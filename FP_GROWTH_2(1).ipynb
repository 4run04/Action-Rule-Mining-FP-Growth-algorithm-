# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.11/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2024.12.14)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo
from collections import Counter

def prepare_data():
    # Fetch and prepare the dataset
    credit_approval = fetch_ucirepo(id=27)
    df = pd.DataFrame(credit_approval.data.features)
    df = pd.concat([df, credit_approval.data.targets], axis=1)

    # Handle missing values
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = df[column].fillna(df[column].mode()[0])
        elif pd.api.types.is_numeric_dtype(df[column]):
            df[column] = df[column].fillna(df[column].mean())

    # Discretize numeric columns
    for column in df.columns:
        if df[column].dtype != 'object' and column != 'A16':  # Skip target variable
            try:
                df[column] = pd.qcut(df[column], q=3, labels=['low', 'medium', 'high'])
            except:
                print(f"Could not discretize column {column}")

    return df

# %%
def generate_all_possible_transitions(df):
    # Initialize an empty list to store the feature-value transitions
    feature_value_transitions = []

    # Iterate over each feature in the DataFrame (excluding the target variable 'A16')
    for feature in df.columns:
        if feature != 'A16':  # Skip the target variable
            # Get unique values for the current feature
            feature_values = df[feature].unique()

            # Generate all possible pairs of feature values (old_value, new_value)
            for old_value in feature_values:
                for new_value in feature_values:
                        transition = (feature, old_value, new_value)
                        feature_value_transitions.append(transition)

    return feature_value_transitions

# %%
df=prepare_data()
# Out:
# Could not discretize column A15
# Could not discretize column A11

# %%
atomic_action_sets=generate_all_possible_transitions(df)
atomic_action_sets
# Out:
# [('A15', 0, 0),
#  ('A15', 0, 560),
#  ('A15', 0, 824),
#  ('A15', 0, 3),
#  ('A15', 0, 31285),
#  ('A15', 0, 1349),
#  ('A15', 0, 314),
#  ('A15', 0, 1442),
#  ('A15', 0, 200),
#  ('A15', 0, 2690),
#  ('A15', 0, 245),
#  ('A15', 0, 1208),
#  ('A15', 0, 1260),
#  ('A15', 0, 11),
#  ('A15', 0, 10000),
#  ('A15', 0, 5000),
#  ('A15', 0, 4000),
#  ('A15', 0, 35),
#  ('A15', 0, 713),
#  ('A15', 0, 551),
#  ('A15', 0, 500),
#  ('A15', 0, 300),
#  ('A15', 0, 221),
#  ('A15', 0, 2283),
#  ('A15', 0, 100),
#  ('A15', 0, 15),
#  ('A15', 0, 284),
#  ('A15', 0, 1236),
#  ('A15', 0, 5800),
#  ('A15', 0, 730),
#  ('A15', 0, 400),
#  ('A15', 0, 50000),
#  ('A15', 0, 456),
#  ('A15', 0, 15108),
#  ('A15', 0, 2954),
#  ('A15', 0, 2),
#  ('A15', 0, 20),
#  ('A15', 0, 27),
#  ('A15', 0, 225),
#  ('A15', 0, 1),
#  ('A15', 0, 38),
#  ('A15', 0, 5),
#  ('A15', 0, 130),
#  ('A15', 0, 147),
#  ('A15', 0, 210),
#  ('A15', 0, 11202),
#  ('A15', 0, 1332),
#  ('A15', 0, 50),
#  ('A15', 0, 258),
#  ('A15', 0, 567),
#  ('A15', 0, 1000),
#  ('A15', 0, 2510),
#  ('A15', 0, 809),
#  ('A15', 0, 610),
#  ('A15', 0, 150),
#  ('A15', 0, 51100),
#  ('A15', 0, 367),
#  ('A15', 0, 600),
#  ('A15', 0, 247),
#  ('A15', 0, 375),
#  ('A15', 0, 278),
#  ('A15', 0, 827),
#  ('A15', 0, 2072),
#  ('A15', 0, 582),
#  ('A15', 0, 2300),
#  ('A15', 0, 3065),
#  ('A15', 0, 2200),
#  ('A15', 0, 6),
#  ('A15', 0, 1602),
#  ('A15', 0, 2184),
#  ('A15', 0, 3376),
#  ('A15', 0, 2000),
#  ('A15', 0, 7544),
#  ('A15', 0, 10561),
#  ('A15', 0, 837),
#  ('A15', 0, 11177),
#  ('A15', 0, 639),
#  ('A15', 0, 2028),
#  ('A15', 0, 1065),
#  ('A15', 0, 540),
#  ('A15', 0, 158),
#  ('A15', 0, 15000),
#  ('A15', 0, 3000),
#  ('A15', 0, 3257),
#  ('A15', 0, 1655),
#  ('A15', 0, 1430),
#  ('A15', 0, 7),
#  ('A15', 0, 790),
#  ('A15', 0, 396),
#  ('A15', 0, 678),
#  ('A15', 0, 1187),
#  ('A15', 0, 6590),
#  ('A15', 0, 168),
#  ('A15', 0, 1270),
#  ('A15', 0, 1210),
#  ('A15', 0, 742),
#  ('A15', 0, 8851),
#  ('A15', 0, 7059),
#  ('A15', 0, 1704),
#  ('A15', 0, 857),
#  ('A15', 0, 6700),
#  ('A15', 0, 2503),
#  ('A15', 0, 9800),
#  ('A15', 0, 196),
#  ('A15', 0, 14),
#  ('A15', 0, 26726),
#  ('A15', 0, 18027),
#  ('A15', 0, 99),
#  ('A15', 0, 444),
#  ('A15', 0, 1200),
#  ('A15', 0, 2010),
#  ('A15', 0, 13),
#  ('A15', 0, 120),
#  ('A15', 0, 32),
#  ('A15', 0, 722),
#  ('A15', 0, 40),
#  ('A15', 0, 484),
#  ('A15', 0, 204),
#  ('A15', 0, 98),
#  ('A15', 0, 5552),
#  ('A15', 0, 105),
#  ('A15', 0, 2803),
#  ('A15', 0, 126),
#  ('A15', 0, 4),
#  ('A15', 0, 21),
#  ('A15', 0, 173),
#  ('A15', 0, 10),
#  ('A15', 0, 25),
#  ('A15', 0, 42),
#  ('A15', 0, 100000),
#  ('A15', 0, 113),
#  ('A15', 0, 8),
#  ('A15', 0, 44),
#  ('A15', 0, 2732),
#  ('A15', 0, 179),
#  ('A15', 0, 16),
#  ('A15', 0, 1062),
#  ('A15', 0, 251),
#  ('A15', 0, 228),
#  ('A15', 0, 67),
#  ('A15', 0, 12),
#  ('A15', 0, 122),
#  ('A15', 0, 4208),
#  ('A15', 0, 1300),
#  ('A15', 0, 112),
#  ('A15', 0, 1110),
#  ('A15', 0, 1004),
#  ('A15', 0, 286),
#  ('A15', 0, 4500),
#  ('A15', 0, 1212),
#  ('A15', 0, 195),
#  ('A15', 0, 87),
#  ('A15', 0, 17),
#  ('A15', 0, 184),
#  ('A15', 0, 140),
#  ('A15', 0, 18),
#  ('A15', 0, 146),
#  ('A15', 0, 22),
#  ('A15', 0, 55),
#  ('A15', 0, 70),
#  ('A15', 0, 60),
#  ('A15', 0, 1058),
#  ('A15', 0, 769),
#  ('A15', 0, 5200),
#  ('A15', 0, 19),
#  ('A15', 0, 316),
#  ('A15', 0, 350),
#  ('A15', 0, 3552),
#  ('A15', 0, 687),
#  ('A15', 0, 1950),
#  ('A15', 0, 53),
#  ('A15', 0, 41),
#  ('A15', 0, 33),
#  ('A15', 0, 80),
#  ('A15', 0, 351),
#  ('A15', 0, 2100),
#  ('A15', 0, 475),
#  ('A15', 0, 892),
#  ('A15', 0, 4607),
#  ('A15', 0, 2206),
#  ('A15', 0, 5860),
#  ('A15', 0, 28),
#  ('A15', 0, 1391),
#  ('A15', 0, 2279),
#  ('A15', 0, 591),
#  ('A15', 0, 960),
#  ('A15', 0, 690),
#  ('A15', 0, 234),
#  ('A15', 0, 800),
#  ('A15', 0, 990),
#  ('A15', 0, 2197),
#  ('A15', 0, 90),
#  ('A15', 0, 340),
#  ('A15', 0, 347),
#  ('A15', 0, 327),
#  ('A15', 0, 4071),
#  ('A15', 0, 109),
#  ('A15', 0, 1249),
#  ('A15', 0, 134),
#  ('A15', 0, 1344),
#  ('A15', 0, 321),
#  ('A15', 0, 948),
#  ('A15', 0, 2079),
#  ('A15', 0, 2384),
#  ('A15', 0, 458),
#  ('A15', 0, 5298),
#  ('A15', 0, 162),
#  ('A15', 0, 1583),
#  ('A15', 0, 58),
#  ('A15', 0, 59),
#  ('A15', 0, 1400),
#  ('A15', 0, 1465),
#  ('A15', 0, 8000),
#  ('A15', 0, 4700),
#  ('A15', 0, 1097),
#  ('A15', 0, 3290),
#  ('A15', 0, 13212),
#  ('A15', 0, 5777),
#  ('A15', 0, 5124),
#  ('A15', 0, 23),
#  ('A15', 0, 4159),
#  ('A15', 0, 918),
#  ('A15', 0, 768),
#  ('A15', 0, 283),
#  ('A15', 0, 108),
#  ('A15', 0, 9),
#  ('A15', 0, 68),
#  ('A15', 0, 587),
#  ('A15', 0, 141),
#  ('A15', 0, 501),
#  ('A15', 0, 160),
#  ('A15', 0, 390),
#  ('A15', 0, 154),
#  ('A15', 0, 117),
#  ('A15', 0, 246),
#  ('A15', 0, 237),
#  ('A15', 0, 364),
#  ('A15', 0, 537),
#  ('A15', 0, 394),
#  ('A15', 0, 750),
#  ('A15', 560, 0),
#  ('A15', 560, 560),
#  ('A15', 560, 824),
#  ('A15', 560, 3),
#  ('A15', 560, 31285),
#  ('A15', 560, 1349),
#  ('A15', 560, 314),
#  ('A15', 560, 1442),
#  ('A15', 560, 200),
#  ('A15', 560, 2690),
#  ('A15', 560, 245),
#  ('A15', 560, 1208),
#  ('A15', 560, 1260),
#  ('A15', 560, 11),
#  ('A15', 560, 10000),
#  ('A15', 560, 5000),
#  ('A15', 560, 4000),
#  ('A15', 560, 35),
#  ('A15', 560, 713),
#  ('A15', 560, 551),
#  ('A15', 560, 500),
#  ('A15', 560, 300),
#  ('A15', 560, 221),
#  ('A15', 560, 2283),
#  ('A15', 560, 100),
#  ('A15', 560, 15),
#  ('A15', 560, 284),
#  ('A15', 560, 1236),
#  ('A15', 560, 5800),
#  ('A15', 560, 730),
#  ('A15', 560, 400),
#  ('A15', 560, 50000),
#  ('A15', 560, 456),
#  ('A15', 560, 15108),
#  ('A15', 560, 2954),
#  ('A15', 560, 2),
#  ('A15', 560, 20),
#  ('A15', 560, 27),
#  ('A15', 560, 225),
#  ('A15', 560, 1),
#  ('A15', 560, 38),
#  ('A15', 560, 5),
#  ('A15', 560, 130),
#  ('A15', 560, 147),
#  ('A15', 560, 210),
#  ('A15', 560, 11202),
#  ('A15', 560, 1332),
#  ('A15', 560, 50),
#  ('A15', 560, 258),
#  ('A15', 560, 567),
#  ('A15', 560, 1000),
#  ('A15', 560, 2510),
#  ('A15', 560, 809),
#  ('A15', 560, 610),
#  ('A15', 560, 150),
#  ('A15', 560, 51100),
#  ('A15', 560, 367),
#  ('A15', 560, 600),
#  ('A15', 560, 247),
#  ('A15', 560, 375),
#  ('A15', 560, 278),
#  ('A15', 560, 827),
#  ('A15', 560, 2072),
#  ('A15', 560, 582),
#  ('A15', 560, 2300),
#  ('A15', 560, 3065),
#  ('A15', 560, 2200),
#  ('A15', 560, 6),
#  ('A15', 560, 1602),
#  ('A15', 560, 2184),
#  ('A15', 560, 3376),
#  ('A15', 560, 2000),
#  ('A15', 560, 7544),
#  ('A15', 560, 10561),
#  ('A15', 560, 837),
#  ('A15', 560, 11177),
#  ('A15', 560, 639),
#  ('A15', 560, 2028),
#  ('A15', 560, 1065),
#  ('A15', 560, 540),
#  ('A15', 560, 158),
#  ('A15', 560, 15000),
#  ('A15', 560, 3000),
#  ('A15', 560, 3257),
#  ('A15', 560, 1655),
#  ('A15', 560, 1430),
#  ('A15', 560, 7),
#  ('A15', 560, 790),
#  ('A15', 560, 396),
#  ('A15', 560, 678),
#  ('A15', 560, 1187),
#  ('A15', 560, 6590),
#  ('A15', 560, 168),
#  ('A15', 560, 1270),
#  ('A15', 560, 1210),
#  ('A15', 560, 742),
#  ('A15', 560, 8851),
#  ('A15', 560, 7059),
#  ('A15', 560, 1704),
#  ('A15', 560, 857),
#  ('A15', 560, 6700),
#  ('A15', 560, 2503),
#  ('A15', 560, 9800),
#  ('A15', 560, 196),
#  ('A15', 560, 14),
#  ('A15', 560, 26726),
#  ('A15', 560, 18027),
#  ('A15', 560, 99),
#  ('A15', 560, 444),
#  ('A15', 560, 1200),
#  ('A15', 560, 2010),
#  ('A15', 560, 13),
#  ('A15', 560, 120),
#  ('A15', 560, 32),
#  ('A15', 560, 722),
#  ('A15', 560, 40),
#  ('A15', 560, 484),
#  ('A15', 560, 204),
#  ('A15', 560, 98),
#  ('A15', 560, 5552),
#  ('A15', 560, 105),
#  ('A15', 560, 2803),
#  ('A15', 560, 126),
#  ('A15', 560, 4),
#  ('A15', 560, 21),
#  ('A15', 560, 173),
#  ('A15', 560, 10),
#  ('A15', 560, 25),
#  ('A15', 560, 42),
#  ('A15', 560, 100000),
#  ('A15', 560, 113),
#  ('A15', 560, 8),
#  ('A15', 560, 44),
#  ('A15', 560, 2732),
#  ('A15', 560, 179),
#  ('A15', 560, 16),
#  ('A15', 560, 1062),
#  ('A15', 560, 251),
#  ('A15', 560, 228),
#  ('A15', 560, 67),
#  ('A15', 560, 12),
#  ('A15', 560, 122),
#  ('A15', 560, 4208),
#  ('A15', 560, 1300),
#  ('A15', 560, 112),
#  ('A15', 560, 1110),
#  ('A15', 560, 1004),
#  ('A15', 560, 286),
#  ('A15', 560, 4500),
#  ('A15', 560, 1212),
#  ('A15', 560, 195),
#  ('A15', 560, 87),
#  ('A15', 560, 17),
#  ('A15', 560, 184),
#  ('A15', 560, 140),
#  ('A15', 560, 18),
#  ('A15', 560, 146),
#  ('A15', 560, 22),
#  ('A15', 560, 55),
#  ('A15', 560, 70),
#  ('A15', 560, 60),
#  ('A15', 560, 1058),
#  ('A15', 560, 769),
#  ('A15', 560, 5200),
#  ('A15', 560, 19),
#  ('A15', 560, 316),
#  ('A15', 560, 350),
#  ('A15', 560, 3552),
#  ('A15', 560, 687),
#  ('A15', 560, 1950),
#  ('A15', 560, 53),
#  ('A15', 560, 41),
#  ('A15', 560, 33),
#  ('A15', 560, 80),
#  ('A15', 560, 351),
#  ('A15', 560, 2100),
#  ('A15', 560, 475),
#  ('A15', 560, 892),
#  ('A15', 560, 4607),
#  ('A15', 560, 2206),
#  ('A15', 560, 5860),
#  ('A15', 560, 28),
#  ('A15', 560, 1391),
#  ('A15', 560, 2279),
#  ('A15', 560, 591),
#  ('A15', 560, 960),
#  ('A15', 560, 690),
#  ('A15', 560, 234),
#  ('A15', 560, 800),
#  ('A15', 560, 990),
#  ('A15', 560, 2197),
#  ('A15', 560, 90),
#  ('A15', 560, 340),
#  ('A15', 560, 347),
#  ('A15', 560, 327),
#  ('A15', 560, 4071),
#  ('A15', 560, 109),
#  ('A15', 560, 1249),
#  ('A15', 560, 134),
#  ('A15', 560, 1344),
#  ('A15', 560, 321),
#  ('A15', 560, 948),
#  ('A15', 560, 2079),
#  ('A15', 560, 2384),
#  ('A15', 560, 458),
#  ('A15', 560, 5298),
#  ('A15', 560, 162),
#  ('A15', 560, 1583),
#  ('A15', 560, 58),
#  ('A15', 560, 59),
#  ('A15', 560, 1400),
#  ('A15', 560, 1465),
#  ('A15', 560, 8000),
#  ('A15', 560, 4700),
#  ('A15', 560, 1097),
#  ('A15', 560, 3290),
#  ('A15', 560, 13212),
#  ('A15', 560, 5777),
#  ('A15', 560, 5124),
#  ('A15', 560, 23),
#  ('A15', 560, 4159),
#  ('A15', 560, 918),
#  ('A15', 560, 768),
#  ('A15', 560, 283),
#  ('A15', 560, 108),
#  ('A15', 560, 9),
#  ('A15', 560, 68),
#  ('A15', 560, 587),
#  ('A15', 560, 141),
#  ('A15', 560, 501),
#  ('A15', 560, 160),
#  ('A15', 560, 390),
#  ('A15', 560, 154),
#  ('A15', 560, 117),
#  ('A15', 560, 246),
#  ('A15', 560, 237),
#  ('A15', 560, 364),
#  ('A15', 560, 537),
#  ('A15', 560, 394),
#  ('A15', 560, 750),
#  ('A15', 824, 0),
#  ('A15', 824, 560),
#  ('A15', 824, 824),
#  ('A15', 824, 3),
#  ('A15', 824, 31285),
#  ('A15', 824, 1349),
#  ('A15', 824, 314),
#  ('A15', 824, 1442),
#  ('A15', 824, 200),
#  ('A15', 824, 2690),
#  ('A15', 824, 245),
#  ('A15', 824, 1208),
#  ('A15', 824, 1260),
#  ('A15', 824, 11),
#  ('A15', 824, 10000),
#  ('A15', 824, 5000),
#  ('A15', 824, 4000),
#  ('A15', 824, 35),
#  ('A15', 824, 713),
#  ('A15', 824, 551),
#  ('A15', 824, 500),
#  ('A15', 824, 300),
#  ('A15', 824, 221),
#  ('A15', 824, 2283),
#  ('A15', 824, 100),
#  ('A15', 824, 15),
#  ('A15', 824, 284),
#  ('A15', 824, 1236),
#  ('A15', 824, 5800),
#  ('A15', 824, 730),
#  ('A15', 824, 400),
#  ('A15', 824, 50000),
#  ('A15', 824, 456),
#  ('A15', 824, 15108),
#  ('A15', 824, 2954),
#  ('A15', 824, 2),
#  ('A15', 824, 20),
#  ('A15', 824, 27),
#  ('A15', 824, 225),
#  ('A15', 824, 1),
#  ('A15', 824, 38),
#  ('A15', 824, 5),
#  ('A15', 824, 130),
#  ('A15', 824, 147),
#  ('A15', 824, 210),
#  ('A15', 824, 11202),
#  ('A15', 824, 1332),
#  ('A15', 824, 50),
#  ('A15', 824, 258),
#  ('A15', 824, 567),
#  ('A15', 824, 1000),
#  ('A15', 824, 2510),
#  ('A15', 824, 809),
#  ('A15', 824, 610),
#  ('A15', 824, 150),
#  ('A15', 824, 51100),
#  ('A15', 824, 367),
#  ('A15', 824, 600),
#  ('A15', 824, 247),
#  ('A15', 824, 375),
#  ('A15', 824, 278),
#  ('A15', 824, 827),
#  ('A15', 824, 2072),
#  ('A15', 824, 582),
#  ('A15', 824, 2300),
#  ('A15', 824, 3065),
#  ('A15', 824, 2200),
#  ('A15', 824, 6),
#  ('A15', 824, 1602),
#  ('A15', 824, 2184),
#  ('A15', 824, 3376),
#  ('A15', 824, 2000),
#  ('A15', 824, 7544),
#  ('A15', 824, 10561),
#  ('A15', 824, 837),
#  ('A15', 824, 11177),
#  ('A15', 824, 639),
#  ('A15', 824, 2028),
#  ('A15', 824, 1065),
#  ('A15', 824, 540),
#  ('A15', 824, 158),
#  ('A15', 824, 15000),
#  ('A15', 824, 3000),
#  ('A15', 824, 3257),
#  ('A15', 824, 1655),
#  ('A15', 824, 1430),
#  ('A15', 824, 7),
#  ('A15', 824, 790),
#  ('A15', 824, 396),
#  ('A15', 824, 678),
#  ('A15', 824, 1187),
#  ('A15', 824, 6590),
#  ('A15', 824, 168),
#  ('A15', 824, 1270),
#  ('A15', 824, 1210),
#  ('A15', 824, 742),
#  ('A15', 824, 8851),
#  ('A15', 824, 7059),
#  ('A15', 824, 1704),
#  ('A15', 824, 857),
#  ('A15', 824, 6700),
#  ('A15', 824, 2503),
#  ('A15', 824, 9800),
#  ('A15', 824, 196),
#  ('A15', 824, 14),
#  ('A15', 824, 26726),
#  ('A15', 824, 18027),
#  ('A15', 824, 99),
#  ('A15', 824, 444),
#  ('A15', 824, 1200),
#  ('A15', 824, 2010),
#  ('A15', 824, 13),
#  ('A15', 824, 120),
#  ('A15', 824, 32),
#  ('A15', 824, 722),
#  ('A15', 824, 40),
#  ('A15', 824, 484),
#  ('A15', 824, 204),
#  ('A15', 824, 98),
#  ('A15', 824, 5552),
#  ('A15', 824, 105),
#  ('A15', 824, 2803),
#  ('A15', 824, 126),
#  ('A15', 824, 4),
#  ('A15', 824, 21),
#  ('A15', 824, 173),
#  ('A15', 824, 10),
#  ('A15', 824, 25),
#  ('A15', 824, 42),
#  ('A15', 824, 100000),
#  ('A15', 824, 113),
#  ('A15', 824, 8),
#  ('A15', 824, 44),
#  ('A15', 824, 2732),
#  ('A15', 824, 179),
#  ('A15', 824, 16),
#  ('A15', 824, 1062),
#  ('A15', 824, 251),
#  ('A15', 824, 228),
#  ('A15', 824, 67),
#  ('A15', 824, 12),
#  ('A15', 824, 122),
#  ('A15', 824, 4208),
#  ('A15', 824, 1300),
#  ('A15', 824, 112),
#  ('A15', 824, 1110),
#  ('A15', 824, 1004),
#  ('A15', 824, 286),
#  ('A15', 824, 4500),
#  ('A15', 824, 1212),
#  ('A15', 824, 195),
#  ('A15', 824, 87),
#  ('A15', 824, 17),
#  ('A15', 824, 184),
#  ('A15', 824, 140),
#  ('A15', 824, 18),
#  ('A15', 824, 146),
#  ('A15', 824, 22),
#  ('A15', 824, 55),
#  ('A15', 824, 70),
#  ('A15', 824, 60),
#  ('A15', 824, 1058),
#  ('A15', 824, 769),
#  ('A15', 824, 5200),
#  ('A15', 824, 19),
#  ('A15', 824, 316),
#  ('A15', 824, 350),
#  ('A15', 824, 3552),
#  ('A15', 824, 687),
#  ('A15', 824, 1950),
#  ('A15', 824, 53),
#  ('A15', 824, 41),
#  ('A15', 824, 33),
#  ('A15', 824, 80),
#  ('A15', 824, 351),
#  ('A15', 824, 2100),
#  ('A15', 824, 475),
#  ('A15', 824, 892),
#  ('A15', 824, 4607),
#  ('A15', 824, 2206),
#  ('A15', 824, 5860),
#  ('A15', 824, 28),
#  ('A15', 824, 1391),
#  ('A15', 824, 2279),
#  ('A15', 824, 591),
#  ('A15', 824, 960),
#  ('A15', 824, 690),
#  ('A15', 824, 234),
#  ('A15', 824, 800),
#  ('A15', 824, 990),
#  ('A15', 824, 2197),
#  ('A15', 824, 90),
#  ('A15', 824, 340),
#  ('A15', 824, 347),
#  ('A15', 824, 327),
#  ('A15', 824, 4071),
#  ('A15', 824, 109),
#  ('A15', 824, 1249),
#  ('A15', 824, 134),
#  ('A15', 824, 1344),
#  ('A15', 824, 321),
#  ('A15', 824, 948),
#  ('A15', 824, 2079),
#  ('A15', 824, 2384),
#  ('A15', 824, 458),
#  ('A15', 824, 5298),
#  ('A15', 824, 162),
#  ('A15', 824, 1583),
#  ('A15', 824, 58),
#  ('A15', 824, 59),
#  ('A15', 824, 1400),
#  ('A15', 824, 1465),
#  ('A15', 824, 8000),
#  ('A15', 824, 4700),
#  ('A15', 824, 1097),
#  ('A15', 824, 3290),
#  ('A15', 824, 13212),
#  ('A15', 824, 5777),
#  ('A15', 824, 5124),
#  ('A15', 824, 23),
#  ('A15', 824, 4159),
#  ('A15', 824, 918),
#  ('A15', 824, 768),
#  ('A15', 824, 283),
#  ('A15', 824, 108),
#  ('A15', 824, 9),
#  ('A15', 824, 68),
#  ('A15', 824, 587),
#  ('A15', 824, 141),
#  ('A15', 824, 501),
#  ('A15', 824, 160),
#  ('A15', 824, 390),
#  ('A15', 824, 154),
#  ('A15', 824, 117),
#  ('A15', 824, 246),
#  ('A15', 824, 237),
#  ('A15', 824, 364),
#  ('A15', 824, 537),
#  ('A15', 824, 394),
#  ('A15', 824, 750),
#  ('A15', 3, 0),
#  ('A15', 3, 560),
#  ('A15', 3, 824),
#  ('A15', 3, 3),
#  ('A15', 3, 31285),
#  ('A15', 3, 1349),
#  ('A15', 3, 314),
#  ('A15', 3, 1442),
#  ('A15', 3, 200),
#  ('A15', 3, 2690),
#  ('A15', 3, 245),
#  ('A15', 3, 1208),
#  ('A15', 3, 1260),
#  ('A15', 3, 11),
#  ('A15', 3, 10000),
#  ('A15', 3, 5000),
#  ('A15', 3, 4000),
#  ('A15', 3, 35),
#  ('A15', 3, 713),
#  ('A15', 3, 551),
#  ('A15', 3, 500),
#  ('A15', 3, 300),
#  ('A15', 3, 221),
#  ('A15', 3, 2283),
#  ('A15', 3, 100),
#  ('A15', 3, 15),
#  ('A15', 3, 284),
#  ('A15', 3, 1236),
#  ('A15', 3, 5800),
#  ('A15', 3, 730),
#  ('A15', 3, 400),
#  ('A15', 3, 50000),
#  ('A15', 3, 456),
#  ('A15', 3, 15108),
#  ('A15', 3, 2954),
#  ('A15', 3, 2),
#  ('A15', 3, 20),
#  ('A15', 3, 27),
#  ('A15', 3, 225),
#  ('A15', 3, 1),
#  ('A15', 3, 38),
#  ('A15', 3, 5),
#  ('A15', 3, 130),
#  ('A15', 3, 147),
#  ('A15', 3, 210),
#  ('A15', 3, 11202),
#  ('A15', 3, 1332),
#  ('A15', 3, 50),
#  ('A15', 3, 258),
#  ('A15', 3, 567),
#  ('A15', 3, 1000),
#  ('A15', 3, 2510),
#  ('A15', 3, 809),
#  ('A15', 3, 610),
#  ('A15', 3, 150),
#  ('A15', 3, 51100),
#  ('A15', 3, 367),
#  ('A15', 3, 600),
#  ('A15', 3, 247),
#  ('A15', 3, 375),
#  ('A15', 3, 278),
#  ('A15', 3, 827),
#  ('A15', 3, 2072),
#  ('A15', 3, 582),
#  ('A15', 3, 2300),
#  ('A15', 3, 3065),
#  ('A15', 3, 2200),
#  ('A15', 3, 6),
#  ('A15', 3, 1602),
#  ('A15', 3, 2184),
#  ('A15', 3, 3376),
#  ('A15', 3, 2000),
#  ('A15', 3, 7544),
#  ('A15', 3, 10561),
#  ('A15', 3, 837),
#  ('A15', 3, 11177),
#  ('A15', 3, 639),
#  ('A15', 3, 2028),
#  ('A15', 3, 1065),
#  ('A15', 3, 540),
#  ('A15', 3, 158),
#  ('A15', 3, 15000),
#  ('A15', 3, 3000),
#  ('A15', 3, 3257),
#  ('A15', 3, 1655),
#  ('A15', 3, 1430),
#  ('A15', 3, 7),
#  ('A15', 3, 790),
#  ('A15', 3, 396),
#  ('A15', 3, 678),
#  ('A15', 3, 1187),
#  ('A15', 3, 6590),
#  ('A15', 3, 168),
#  ('A15', 3, 1270),
#  ('A15', 3, 1210),
#  ('A15', 3, 742),
#  ('A15', 3, 8851),
#  ('A15', 3, 7059),
#  ('A15', 3, 1704),
#  ('A15', 3, 857),
#  ('A15', 3, 6700),
#  ('A15', 3, 2503),
#  ('A15', 3, 9800),
#  ('A15', 3, 196),
#  ('A15', 3, 14),
#  ('A15', 3, 26726),
#  ('A15', 3, 18027),
#  ('A15', 3, 99),
#  ('A15', 3, 444),
#  ('A15', 3, 1200),
#  ('A15', 3, 2010),
#  ('A15', 3, 13),
#  ('A15', 3, 120),
#  ('A15', 3, 32),
#  ('A15', 3, 722),
#  ('A15', 3, 40),
#  ('A15', 3, 484),
#  ('A15', 3, 204),
#  ('A15', 3, 98),
#  ('A15', 3, 5552),
#  ('A15', 3, 105),
#  ('A15', 3, 2803),
#  ('A15', 3, 126),
#  ('A15', 3, 4),
#  ('A15', 3, 21),
#  ('A15', 3, 173),
#  ('A15', 3, 10),
#  ('A15', 3, 25),
#  ('A15', 3, 42),
#  ('A15', 3, 100000),
#  ('A15', 3, 113),
#  ('A15', 3, 8),
#  ('A15', 3, 44),
#  ('A15', 3, 2732),
#  ('A15', 3, 179),
#  ('A15', 3, 16),
#  ('A15', 3, 1062),
#  ('A15', 3, 251),
#  ('A15', 3, 228),
#  ('A15', 3, 67),
#  ('A15', 3, 12),
#  ('A15', 3, 122),
#  ('A15', 3, 4208),
#  ('A15', 3, 1300),
#  ('A15', 3, 112),
#  ('A15', 3, 1110),
#  ('A15', 3, 1004),
#  ('A15', 3, 286),
#  ('A15', 3, 4500),
#  ('A15', 3, 1212),
#  ('A15', 3, 195),
#  ('A15', 3, 87),
#  ('A15', 3, 17),
#  ('A15', 3, 184),
#  ('A15', 3, 140),
#  ('A15', 3, 18),
#  ('A15', 3, 146),
#  ('A15', 3, 22),
#  ('A15', 3, 55),
#  ('A15', 3, 70),
#  ('A15', 3, 60),
#  ('A15', 3, 1058),
#  ('A15', 3, 769),
#  ('A15', 3, 5200),
#  ('A15', 3, 19),
#  ('A15', 3, 316),
#  ('A15', 3, 350),
#  ('A15', 3, 3552),
#  ('A15', 3, 687),
#  ('A15', 3, 1950),
#  ('A15', 3, 53),
#  ('A15', 3, 41),
#  ('A15', 3, 33),
#  ('A15', 3, 80),
#  ('A15', 3, 351),
#  ('A15', 3, 2100),
#  ('A15', 3, 475),
#  ('A15', 3, 892),
#  ('A15', 3, 4607),
#  ('A15', 3, 2206),
#  ('A15', 3, 5860),
#  ('A15', 3, 28),
#  ('A15', 3, 1391),
#  ('A15', 3, 2279),
#  ('A15', 3, 591),
#  ('A15', 3, 960),
#  ('A15', 3, 690),
#  ('A15', 3, 234),
#  ('A15', 3, 800),
#  ('A15', 3, 990),
#  ('A15', 3, 2197),
#  ('A15', 3, 90),
#  ('A15', 3, 340),
#  ('A15', 3, 347),
#  ('A15', 3, 327),
#  ('A15', 3, 4071),
#  ('A15', 3, 109),
#  ('A15', 3, 1249),
#  ('A15', 3, 134),
#  ('A15', 3, 1344),
#  ('A15', 3, 321),
#  ('A15', 3, 948),
#  ('A15', 3, 2079),
#  ('A15', 3, 2384),
#  ('A15', 3, 458),
#  ('A15', 3, 5298),
#  ('A15', 3, 162),
#  ('A15', 3, 1583),
#  ('A15', 3, 58),
#  ('A15', 3, 59),
#  ('A15', 3, 1400),
#  ('A15', 3, 1465),
#  ('A15', 3, 8000),
#  ('A15', 3, 4700),
#  ('A15', 3, 1097),
#  ('A15', 3, 3290),
#  ('A15', 3, 13212),
#  ('A15', 3, 5777),
#  ('A15', 3, 5124),
#  ('A15', 3, 23),
#  ('A15', 3, 4159),
#  ('A15', 3, 918),
#  ('A15', 3, 768),
#  ('A15', 3, 283),
#  ('A15', 3, 108),
#  ('A15', 3, 9),
#  ('A15', 3, 68),
#  ('A15', 3, 587),
#  ('A15', 3, 141),
#  ('A15', 3, 501),
#  ('A15', 3, 160),
#  ('A15', 3, 390),
#  ('A15', 3, 154),
#  ('A15', 3, 117),
#  ('A15', 3, 246),
#  ('A15', 3, 237),
#  ('A15', 3, 364),
#  ('A15', 3, 537),
#  ('A15', 3, 394),
#  ('A15', 3, 750),
#  ('A15', 31285, 0),
#  ('A15', 31285, 560),
#  ('A15', 31285, 824),
#  ('A15', 31285, 3),
#  ('A15', 31285, 31285),
#  ('A15', 31285, 1349),
#  ('A15', 31285, 314),
#  ('A15', 31285, 1442),
#  ('A15', 31285, 200),
#  ('A15', 31285, 2690),
#  ('A15', 31285, 245),
#  ('A15', 31285, 1208),
#  ('A15', 31285, 1260),
#  ('A15', 31285, 11),
#  ('A15', 31285, 10000),
#  ('A15', 31285, 5000),
#  ('A15', 31285, 4000),
#  ('A15', 31285, 35),
#  ('A15', 31285, 713),
#  ('A15', 31285, 551),
#  ('A15', 31285, 500),
#  ('A15', 31285, 300),
#  ('A15', 31285, 221),
#  ('A15', 31285, 2283),
#  ('A15', 31285, 100),
#  ('A15', 31285, 15),
#  ('A15', 31285, 284),
#  ('A15', 31285, 1236),
#  ('A15', 31285, 5800),
#  ('A15', 31285, 730),
#  ('A15', 31285, 400),
#  ('A15', 31285, 50000),
#  ('A15', 31285, 456),
#  ('A15', 31285, 15108),
#  ('A15', 31285, 2954),
#  ('A15', 31285, 2),
#  ('A15', 31285, 20),
#  ('A15', 31285, 27),
#  ('A15', 31285, 225),
#  ('A15', 31285, 1),
#  ...]

# %%
positive_df=df[df['A16']=='+'].drop(['A16'],axis=1)
negative_df=df[df['A16']=='-'].drop(['A16'],axis=1)

# %%
import collections
posi_freq_table=positive_df.apply(collections.Counter)
neg_freq_table=negative_df.apply(collections.Counter)

# %%
def create_action_table(positive_df, negative_df):
    # Initialize an empty list to store the action rules
    action_table = []

    # Compare each row in negative_df with every row in positive_df
    for _, neg_row in negative_df.iterrows():
        for _, pos_row in positive_df.iterrows():
            # Identify feature differences between negative and positive rows
            changes = []
            for feature in positive_df.columns:
                if neg_row[feature] != pos_row[feature]:
                    changes.append((feature, neg_row[feature], pos_row[feature]))  # (Feature, old_value, new_value)
            if changes:
                action_table.append(changes)  # Add changes for this comparison

    return action_table

# %%
support_atomic_actionsets={}
for (feat,lhs,rhs) in atomic_action_sets:
  support_atomic_actionsets[(feat,lhs,rhs)]=posi_freq_table[feat][lhs]*neg_freq_table[feat][rhs]

# %%
min_support=4000
best_atomic_actionsets=[]
for i,j in support_atomic_actionsets.items():
  if j>=min_support:
    best_atomic_actionsets.append((i,j))

# %%
best_atomic_actionsets=sorted(best_atomic_actionsets,key=lambda x:x[1],reverse=True)
best_atomic_actionsets
# Out:
# [(('A13', 'g', 'g'), 97006),
#  (('A9', 't', 'f'), 86904),
#  (('A5', 'g', 'g'), 68900),
#  (('A4', 'u', 'u'), 68900),
#  (('A10', 't', 'f'), 62073),
#  (('A1', 'b', 'b'), 56639),
#  (('A7', 'v', 'v'), 40655),
#  (('A12', 'f', 'f'), 34293),
#  (('A12', 't', 'f'), 31098),
#  (('A5', 'g', 'p'), 30680),
#  (('A4', 'u', 'y'), 30680),
#  (('A11', 0, 0), 29106),
#  (('A10', 'f', 'f'), 29106),
#  (('A12', 'f', 't'), 27370),
#  (('A8', 'high', 'low'), 26671),
#  (('A1', 'a', 'b'), 26558),
#  (('A12', 't', 't'), 24820),
#  (('A1', 'b', 'a'), 23408),
#  (('A14', 'low', 'medium'), 22320),
#  (('A9', 't', 't'), 21868),
#  (('A3', 'high', 'low'), 21509),
#  (('A15', 0, 0), 20566),
#  (('A7', 'h', 'v'), 20445),
#  (('A8', 'high', 'medium'), 20115),
#  (('A14', 'low', 'high'), 18720),
#  (('A8', 'medium', 'low'), 18437),
#  (('A3', 'high', 'medium'), 18221),
#  (('A2', 'high', 'low'), 18034),
#  (('A10', 't', 't'), 17974),
#  (('A2', 'high', 'medium'), 17653),
#  (('A14', 'high', 'medium'), 15345),
#  (('A14', 'low', 'low'), 14112),
#  (('A8', 'medium', 'medium'), 13905),
#  (('A3', 'medium', 'low'), 13816),
#  (('A2', 'medium', 'low'), 13064),
#  (('A2', 'high', 'high'), 12954),
#  (('A3', 'low', 'low'), 12874),
#  (('A14', 'high', 'high'), 12870),
#  (('A2', 'medium', 'medium'), 12788),
#  (('A3', 'high', 'high'), 12741),
#  (('A2', 'low', 'low'), 12496),
#  (('A2', 'low', 'medium'), 12232),
#  (('A13', 'g', 's'), 12054),
#  (('A5', 'p', 'g'), 11925),
#  (('A4', 'y', 'u'), 11925),
#  (('A3', 'medium', 'medium'), 11704),
#  (('A1', 'a', 'a'), 10976),
#  (('A3', 'low', 'medium'), 10906),
#  (('A11', 1, 0), 10395),
#  (('A8', 'high', 'high'), 10281),
#  (('A14', 'medium', 'medium'), 9920),
#  (('A8', 'low', 'low'), 9845),
#  (('A14', 'high', 'low'), 9702),
#  (('A2', 'medium', 'high'), 9384),
#  (('A2', 'low', 'high'), 8976),
#  (('A7', 'v', 'h'), 8823),
#  (('A7', 'v', 'ff'), 8477),
#  (('A10', 'f', 't'), 8428),
#  (('A14', 'medium', 'high'), 8320),
#  (('A3', 'medium', 'high'), 8184),
#  (('A3', 'low', 'high'), 7626),
#  (('A8', 'low', 'medium'), 7425),
#  (('A8', 'medium', 'high'), 7107),
#  (('A9', 'f', 'f'), 7038),
#  (('A14', 'medium', 'low'), 6272),
#  (('A11', 6, 0), 5940),
#  (('A11', 3, 0), 5940),
#  (('A7', 'v', 'bb'), 5882),
#  (('A7', 'bb', 'v'), 5875),
#  (('A11', 2, 0), 5643),
#  (('A11', 11, 0), 5346),
#  (('A5', 'p', 'p'), 5310),
#  (('A4', 'y', 'y'), 5310),
#  (('A6', 'c', 'c'), 5280),
#  (('A13', 's', 'g'), 5070),
#  (('A11', 5, 0), 4752),
#  (('A11', 7, 0), 4455),
#  (('A7', 'h', 'h'), 4437),
#  (('A7', 'h', 'ff'), 4263),
#  (('A6', 'q', 'c'), 4080)]

# %%
action_table=create_action_table(positive_df,negative_df)
action_table
# Out:
# [[('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 560),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 824),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 3),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'medium')],
#  [('A14', 'high', 'medium'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'low')],
#  [('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 31285),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'r'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 1349),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 314),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'k'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 1442),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 200),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'k'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 2690),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'k'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 10),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'k'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 245),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 10),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'd'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 1208),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 17),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c')],
#  [('A12', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 1260),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 11),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'i'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 17),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'd'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 10000),
#   ('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 8),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 5000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 15),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'i'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 4000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 560),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 35),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 713),
#   ('A13', 's', 'g'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 551),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 500),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'ff'),
#   ('A6', 'e', 'ff'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 221),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 2283),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c')],
#  [('A15', 0, 100),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 15),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 40),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 284),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 1236),
#   ('A13', 's', 'g'),
#   ('A11', 0, 23),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 300),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A13', 's', 'g'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A13', 's', 'g'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 5800),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 200),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A9', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 730),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'd')],
#  [('A15', 0, 400),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 50000),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 456),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 15108),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 2954),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 500),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 11202),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 15),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'k'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 1332),
#   ('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 50),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 258),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 67),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc')],
#  [('A15', 0, 567),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 1000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 2510),
#   ('A13', 's', 'g'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'm'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 809),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 610),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A12', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'z'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 150),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 51100),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 367),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 1000),
#   ('A13', 's', 'g'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q')],
#  [('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 1000),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 600),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 5000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 247),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 15),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'ff'),
#   ('A6', 'e', 'j'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 375),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 8),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 278),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 827),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 2072),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 582),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 2300),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 14),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 3065),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'c'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 2200),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 14),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 6),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 1602),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 14),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'm'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 2184),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'j'),
#   ('A6', 'e', 'j'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 3376),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 14),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'z'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'k'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 2000),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A6', 'e', 'm'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 7544),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 15),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 20),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium')],
#  [('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'h'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 10561),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 837),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 400),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 11177),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 639),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A13', 's', 'g'),
#   ('A9', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'd'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 2028),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'k'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'k'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 1065),
#   ('A13', 's', 'g'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low')],
#  [('A14', 'high', 'low'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa')],
#  [('A15', 0, 150),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 540),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 158),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 14),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 15000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 20),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 6),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 3000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 3257),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 1655),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 500),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'aa'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 3065),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 1430),
#   ('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'low')],
#  [('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 600),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'i'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 7),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 8),
#   ('A10', 'f', 't'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 790),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 560),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 396),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 678),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 600),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 1187),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 6590),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 8),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'p'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 168),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q')],
#  [('A15', 0, 1270),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'k'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 1210),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 16),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 14),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'd'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y')],
#  [('A15', 0, 1000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 15),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'ff'),
#   ('A6', 'e', 'ff'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 742),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'i'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium')],
#  [('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 8),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 8851),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'ff'),
#   ('A6', 'e', 'ff'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 500),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'z'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'k'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 7059),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 1704),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 857),
#   ('A13', 's', 'g'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 500),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w')],
#  [('A15', 0, 6700),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 13),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'i'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 2503),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 9800),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 196),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 14),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 26726),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'i'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 18027),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium')],
#  [('A15', 0, 2000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'cc'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 99),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 444),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A6', 'e', 'c')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 1200),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'z'),
#   ('A2', 'medium', 'high')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 3000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A2', 'medium', 'low')],
#  [('A13', 's', 'g'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 40),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'n'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'p'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 100000),
#   ('A13', 's', 'p'),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'o'),
#   ('A6', 'e', 'ff'),
#   ('A5', 'g', 'gg'),
#   ('A4', 'u', 'l'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 1),
#   ('A9', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A6', 'e', 'm'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 113),
#   ('A13', 's', 'g'),
#   ('A9', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 8),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A9', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'ff'),
#   ('A6', 'e', 'cc'),
#   ('A5', 'g', 'gg'),
#   ('A4', 'u', 'l'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 44),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 2732),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'k'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 892),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 2000),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 4607),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 14),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'm'),
#   ('A2', 'medium', 'high')],
#  [('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 2206),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 5860),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 28),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'low')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low')],
#  [('A15', 0, 1391),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 2279),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 10),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'cc'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 100),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'ff'),
#   ('A6', 'e', 'ff'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 7),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 5000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 16),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c')],
#  [('A15', 0, 591),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A2', 'medium', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 500),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 19),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 19),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 1000),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A15', 0, 960),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'j'),
#   ('A6', 'e', 'j'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'dd'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'h'),
#   ('A6', 'e', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x')],
#  [('A15', 0, 99),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'high'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'aa'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 690),
#   ('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'c'),
#   ('A3', 'high', 'low'),
#   ('A2', 'medium', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'q'),
#   ('A3', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A13', 's', 'g'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'medium', 'low'),
#   ('A7', 'bb', 'v'),
#   ('A6', 'e', 'x'),
#   ('A3', 'high', 'medium'),
#   ('A2', 'medium', 'high')],
#  [('A15', 0, 234),
#   ('A14', 'high', 'medium'),
# ...
#   ('A2', 'high', 'medium'),
#   ('A1', 'a', 'b')],
#  [('A15', 0, 150),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'cc', 'c'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'medium'),
#   ('A1', 'a', 'b')],
#  [('A14', 'high', 'medium'),
#   ('A13', 'g', 'p'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'high', 'low'),
#   ('A6', 'cc', 'c'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'low'),
#   ('A1', 'a', 'b')],
#  [('A15', 0, 6),
#   ('A9', 't', 'f'),
#   ('A8', 'high', 'low'),
#   ('A6', 'cc', 'w'),
#   ('A3', 'medium', 'high'),
#   ('A1', 'a', 'b')],
#  [('A8', 'high', 'low'),
#   ('A6', 'cc', 'k'),
#   ('A3', 'medium', 'low'),
#   ('A1', 'a', 'b')],
#  [('A15', 0, 23),
#   ('A12', 't', 'f'),
#   ('A8', 'high', 'low'),
#   ('A7', 'v', 'bb'),
#   ('A6', 'cc', 'c'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'medium'),
#   ('A1', 'a', 'b')],
#  [('A15', 0, 4159), ('A11', 0, 8), ('A10', 'f', 't'), ('A6', 'cc', 'c')],
#  [('A15', 0, 918),
#   ('A14', 'high', 'low'),
#   ('A12', 't', 'f'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A6', 'cc', 'aa'),
#   ('A3', 'medium', 'high'),
#   ('A2', 'high', 'low')],
#  [('A15', 0, 768),
#   ('A12', 't', 'f'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A9', 't', 'f'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'cc', 'q'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'low'),
#   ('A1', 'a', 'b')],
#  [('A15', 0, 3000),
#   ('A14', 'high', 'medium'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'cc', 'c'),
#   ('A2', 'high', 'low'),
#   ('A1', 'a', 'b')],
#  [('A15', 0, 500),
#   ('A12', 't', 'f'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'cc', 'k'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'high', 'low'),
#   ('A6', 'cc', 'c'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'low'),
#   ('A1', 'a', 'b')],
#  [('A14', 'high', 'low'),
#   ('A13', 'g', 's'),
#   ('A9', 't', 'f'),
#   ('A7', 'v', 'j'),
#   ('A6', 'cc', 'c'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'low'),
#   ('A1', 'a', 'b')],
#  [('A14', 'high', 'medium'),
#   ('A13', 'g', 'p'),
#   ('A12', 't', 'f'),
#   ('A9', 't', 'f'),
#   ('A8', 'high', 'low'),
#   ('A6', 'cc', 'c'),
#   ('A3', 'medium', 'low'),
#   ('A2', 'high', 'medium')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'w'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 560),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 824),
#   ('A13', 's', 'g'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'q'),
#   ('A2', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 3),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'w'),
#   ('A3', 'low', 'medium'),
#   ('A2', 'high', 'medium')],
#  [('A14', 'high', 'medium'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'w'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low')],
#  [('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A3', 'low', 'medium'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 31285),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'r'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 1349),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 314),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'k'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y')],
#  [('A15', 0, 1442),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A6', 'm', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'low', 'medium')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A9', 't', 'f'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'c'),
#   ('A2', 'high', 'low')],
#  [('A15', 0, 200),
#   ('A13', 's', 'g'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'c'),
#   ('A3', 'low', 'medium'),
#   ('A2', 'high', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'k'),
#   ('A3', 'low', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 2690),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A9', 't', 'f'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'k'),
#   ('A3', 'low', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'high'),
#   ('A1', 'b', 'a')],
#  [('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 10),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'k'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'low', 'medium')],
#  [('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 245),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 10),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'd'),
#   ('A2', 'high', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 1208),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 17),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'c'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'medium')],
#  [('A8', 'high', 'medium'), ('A6', 'm', 'c'), ('A2', 'high', 'low')],
#  [('A15', 0, 1260),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'c'),
#   ('A3', 'low', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 11),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'x'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'c'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'bb'),
#   ('A6', 'm', 'i'),
#   ('A3', 'low', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 17),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'bb'),
#   ('A6', 'm', 'd'),
#   ('A3', 'low', 'high')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'e'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 10000),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'w')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'aa'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 8),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'x'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 5000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 15),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'bb'),
#   ('A6', 'm', 'i'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 4000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A6', 'm', 'e'),
#   ('A3', 'low', 'high'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 560),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 35),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'w'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 713),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'medium'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 551),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'x'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 500),
#   ('A13', 's', 'g'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'cc'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'ff'),
#   ('A6', 'm', 'ff'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 221),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'c'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 2283),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'c'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 100),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'w'),
#   ('A2', 'high', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'w'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 15),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 40),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'c'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 284),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'c'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 1236),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 23),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'low'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'q'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'low', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 300),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'medium'),
#   ('A2', 'high', 'medium')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A9', 't', 'f'),
#   ('A7', 'v', 'bb'),
#   ('A6', 'm', 'i'),
#   ('A3', 'low', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A9', 't', 'f'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'c'),
#   ('A2', 'high', 'low')],
#  [('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'c'),
#   ('A2', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'q'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 5800),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'w'),
#   ('A3', 'low', 'medium')],
#  [('A15', 0, 200),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'w'),
#   ('A3', 'low', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'medium')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'w'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'cc'),
#   ('A2', 'high', 'low')],
#  [('A13', 's', 'g'), ('A12', 'f', 't'), ('A7', 'v', 'h'), ('A6', 'm', 'i')],
#  [('A12', 'f', 't'),
#   ('A9', 't', 'f'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'x'),
#   ('A3', 'low', 'medium')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'medium')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 4),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 730),
#   ('A13', 's', 'g'),
#   ('A11', 0, 9),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'd'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 400),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 2),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'q'),
#   ('A5', 'g', 'p'),
#   ('A4', 'u', 'y'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'q'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'medium'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 50000),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'medium')],
#  [('A15', 0, 456),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 11),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'c'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 15108),
#   ('A13', 's', 'g'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'low'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 2954),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 7),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'w'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low')],
#  [('A15', 0, 500),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'x'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 11202),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 15),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'k'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 1332),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 50),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 300),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A11', 0, 1),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'low'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'high')],
#  [('A15', 0, 258),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 67),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'cc'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'medium')],
#  [('A15', 0, 567),
#   ('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 12),
#   ('A10', 'f', 't'),
#   ('A8', 'high', 'medium'),
#   ('A6', 'm', 'aa'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'medium'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 3),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'high'),
#   ('A1', 'b', 'a')],
#  [('A14', 'high', 'medium'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 5),
#   ('A10', 'f', 't'),
#   ('A6', 'm', 'q'),
#   ('A3', 'low', 'high'),
#   ('A2', 'high', 'low'),
#   ('A1', 'b', 'a')],
#  [('A15', 0, 1000),
#   ('A14', 'high', 'low'),
#   ('A13', 's', 'g'),
#   ('A12', 'f', 't'),
#   ('A11', 0, 6),
#   ('A10', 'f', 't'),
#   ('A7', 'v', 'h'),
#   ('A6', 'm', 'x'),
#   ('A3', 'low', 'medium')],
#  ...]

# %%
def prune_and_reorder_action_table(action_table, best_atomic_actionsets):
    """
    Prunes entries from action table that don't meet minimum support and
    reorders remaining entries by descending support.

    Args:
        action_table: List of lists containing action sets
        best_atomic_actionsets: Set of tuples ((feature, old_val, new_val), support)
                               that meet minimum support threshold

    Returns:
        List of pruned and reordered action sets
    """
    # Convert best_atomic_actionsets to a dict for easier lookup of support values
    support_dict = {action[0]: action[1] for action in best_atomic_actionsets}

    pruned_table = []

    # Iterate through each row in action table
    for row in action_table:
        # Check if all actions in the row are in best_atomic_actionsets
        valid_actions = []
        for action in row:
            if action in support_dict:
                # Store tuple of (action, support) for sorting
                valid_actions.append((action, support_dict[action]))

        # If we have valid actions after pruning
        if valid_actions:
            # Sort actions by support value in descending order
            sorted_actions = sorted(valid_actions, key=lambda x: x[1], reverse=True)
            # Keep only the actions, discard support values
            pruned_table.append([action for action, _ in sorted_actions])

    return pruned_table

# Prune and reorder the action table
pruned_action_table = prune_and_reorder_action_table(action_table, best_atomic_actionsets)

# Print first few rows of pruned and reordered action table
print("\nFirst few rows of pruned and reordered action table:")
for i, row in enumerate(pruned_action_table[:5]):
    print(f"Row {i + 1}: {row}")
# Out:
# First few rows of pruned and reordered action table:
# Row 1: [('A12', 't', 'f'), ('A3', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A7', 'bb', 'v'), ('A13', 's', 'g')]
# Row 2: [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A3', 'high', 'medium'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A8', 'medium', 'high'), ('A13', 's', 'g')]
# Row 3: [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A3', 'high', 'low'), ('A13', 's', 'g')]
# Row 4: [('A3', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'medium', 'high'), ('A7', 'bb', 'v'), ('A13', 's', 'g')]
# Row 5: [('A12', 't', 'f'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A7', 'bb', 'v')]

# %%
for i in pruned_action_table:
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# [('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A12', 'f', 't'), ('A1', 'b', 'a'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A13', 'g', 's'), ('A8', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A1', 'b', 'a'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A2', 'medium', 'low'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'b', 'a'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A7', 'h', 'ff')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A10', 'f', 't')]
# [('A1', 'b', 'a'), ('A8', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A8', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A2', 'medium', 'low'), ('A14', 'high', 'low'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'b', 'a'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A13', 'g', 's'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A8', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A2', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'b', 'a'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low')]
# [('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A12', 'f', 't'), ('A14', 'high', 'medium'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'b', 'a'), ('A8', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A1', 'b', 'a'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high')]
# [('A12', 'f', 't'), ('A14', 'high', 'medium'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A8', 'medium', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A8', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A12', 'f', 't'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high')]
# [('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A12', 'f', 't'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A2', 'medium', 'high'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A3', 'medium', 'low'), ('A2', 'medium', 'low'), ('A13', 'g', 's'), ('A5', 'p', 'g'), ('A4', 'y', 'u'), ('A14', 'high', 'low'), ('A8', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'medium', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A5', 'p', 'g'), ('A4', 'y', 'u')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A13', 'g', 's'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A8', 'low', 'medium')]
# [('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A14', 'high', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A3', 'medium', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A13', 'g', 's')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A13', 'g', 's'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'medium')]
# [('A1', 'a', 'b'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A13', 'g', 's'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A2', 'high', 'low'), ('A13', 'g', 's'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A3', 'medium', 'low')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A13', 'g', 's'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A13', 'g', 's')]
# [('A1', 'a', 'b'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A13', 'g', 's'), ('A14', 'high', 'low')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A13', 'g', 's'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'low')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A10', 'f', 't')]
# [('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's'), ('A7', 'h', 'ff')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A2', 'high', 'low')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A7', 'h', 'ff')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A14', 'high', 'low')]
# [('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'low')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A13', 'g', 's'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A2', 'high', 'medium'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low'), ('A13', 'g', 's'), ('A10', 'f', 't')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A2', 'high', 'medium'), ('A14', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A3', 'medium', 'low')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A12', 'f', 't'), ('A7', 'h', 'v'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A8', 'low', 'medium')]
# [('A1', 'a', 'b'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A14', 'high', 'low')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's'), ('A14', 'high', 'low')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A10', 'f', 't')]
# [('A3', 'low', 'medium'), ('A14', 'high', 'low'), ('A7', 'v', 'h'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A2', 'high', 'medium'), ('A7', 'v', 'h')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'low', 'medium'), ('A14', 'high', 'low'), ('A10', 'f', 't'), ('A8', 'medium', 'high')]
# [('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A13', 'g', 's'), ('A3', 'low', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A3', 'low', 'medium'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'medium'), ('A14', 'high', 'medium'), ('A7', 'v', 'h'), ('A8', 'medium', 'high')]
# [('A8', 'medium', 'low'), ('A2', 'high', 'low'), ('A14', 'high', 'low'), ('A3', 'low', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'a', 'b'), ('A14', 'high', 'medium'), ('A7', 'v', 'h'), ('A8', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A12', 'f', 't'), ('A1', 'a', 'b'), ('A3', 'low', 'medium'), ('A14', 'high', 'low'), ('A8', 'medium', 'high')]
# [('A12', 'f', 't'), ('A1', 'a', 'b'), ('A2', 'high', 'low'), ('A14', 'high', 'medium'), ('A7', 'v', 'h'), ('A8', 'medium', 'high')]
# ...
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A10', 'f', 't')]
# [('A14', 'low', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A13', 'g', 's'), ('A3', 'medium', 'high')]
# [('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A13', 'g', 's')]
# [('A12', 't', 'f'), ('A14', 'low', 'high'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A3', 'medium', 'high')]
# [('A8', 'high', 'low'), ('A14', 'low', 'medium'), ('A2', 'high', 'low')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'b', 'a'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A10', 'f', 't')]
# [('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A8', 'high', 'low'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A13', 'g', 's')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A13', 'g', 's'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A2', 'high', 'medium')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'low', 'medium'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A14', 'low', 'high'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A14', 'low', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'low')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A3', 'medium', 'low')]
# [('A8', 'high', 'low'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A8', 'high', 'low'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A3', 'medium', 'low')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'low')]
# [('A1', 'b', 'a'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's'), ('A7', 'h', 'ff')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A14', 'low', 'high'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'b', 'a'), ('A14', 'low', 'high'), ('A2', 'high', 'low')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A14', 'low', 'medium'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A14', 'low', 'high'), ('A3', 'medium', 'low'), ('A10', 'f', 't'), ('A7', 'h', 'ff')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A1', 'b', 'a')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A3', 'medium', 'low')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A2', 'high', 'low'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A2', 'high', 'low')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A1', 'b', 'a'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A13', 'g', 's'), ('A3', 'medium', 'high')]
# [('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A1', 'b', 'a'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A14', 'low', 'high'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A3', 'medium', 'low')]
# [('A1', 'b', 'a'), ('A14', 'low', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A12', 't', 'f'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'low')]
# [('A14', 'low', 'medium'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A2', 'high', 'low')]
# [('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A10', 'f', 't'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A10', 'f', 't')]
# [('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A3', 'medium', 'low'), ('A13', 'g', 's'), ('A10', 'f', 't')]
# [('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'low', 'medium'), ('A2', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A2', 'high', 'medium'), ('A3', 'medium', 'high')]
# [('A8', 'high', 'low'), ('A3', 'medium', 'high'), ('A7', 'h', 'ff')]
# [('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A5', 'g', 'p'), ('A4', 'u', 'y'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'medium'), ('A10', 'f', 't')]
# [('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low')]
# [('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A3', 'medium', 'high')]
# [('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A3', 'medium', 'low')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]
# [('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A14', 'low', 'high'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A10', 'f', 't'), ('A3', 'medium', 'high')]
# [('A12', 't', 'f'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A2', 'high', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A1', 'b', 'a'), ('A7', 'h', 'v'), ('A8', 'high', 'medium'), ('A14', 'low', 'high'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low'), ('A10', 'f', 't')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A7', 'h', 'v'), ('A2', 'high', 'low'), ('A3', 'medium', 'low')]
# [('A2', 'high', 'low'), ('A3', 'medium', 'low'), ('A13', 'g', 's')]
# [('A12', 't', 'f'), ('A8', 'high', 'low'), ('A1', 'b', 'a'), ('A14', 'low', 'medium'), ('A7', 'h', 'v'), ('A2', 'high', 'medium'), ('A3', 'medium', 'low')]

# %%
class FPNode:
    def __init__(self, action=None, count=1, parent=None):
        """Initialize a node in the FP-tree."""
        self.action = action  # (feature, old_value, new_value)
        self.count = count
        self.parent = parent
        self.children = {}
        self.next = None  # Link to next node with same action (for header table)

class FPTree:
    def __init__(self):
        """Initialize the FP-tree structure."""
        self.root = FPNode()  # Root node with no action
        self.header_table = {}  # Maps actions to their first occurrence in tree

    def _update_header_table(self, node):
        """Update the header table with a new node."""
        if node.action in self.header_table:
            # Find the last node in the link list
            current = self.header_table[node.action]
            while current.next:
                current = current.next
            current.next = node
        else:
            self.header_table[node.action] = node

    def insert_action_set(self, action_set):
        """Insert a set of actions into the FP-tree."""
        current = self.root

        for action in action_set:
            if action not in current.children:
                # Create new node
                new_node = FPNode(
                    action=action,
                    parent=current
                )
                current.children[action] = new_node
                self._update_header_table(new_node)
            else:
                # Increment count of existing node
                current.children[action].count += 1

            current = current.children[action]

    def build_tree(self, pruned_action_table):
        """Build the FP-tree from the pruned action table."""
        for action_set in pruned_action_table:
            self.insert_action_set(action_set)

    def print_tree(self, node=None, level=0):
        """Print the FP-tree structure for debugging."""
        if node is None:
            node = self.root
            print("FP-Tree Structure:")

        indent = "  " * level
        action_str = str(node.action) if node.action else "Root"
        print(f"{indent}{action_str} (count: {node.count})")

        for child in node.children.values():
            self.print_tree(child, level + 1)

    def get_frequent_patterns(self, min_support=1):
        """Extract frequent patterns from the FP-tree."""
        patterns = []

        def find_prefix_paths(node):
            """Find all prefix paths for a given node."""
            paths = []
            while node and node.parent:
                if node.parent != self.root:
                    paths.append(node.parent.action)
                node = node.parent
            return paths[::-1] if paths else []

        # For each action in header table
        for action, first_node in self.header_table.items():
            pattern_base = []
            current = first_node

            # Follow node links to collect all paths
            while current:
                path = find_prefix_paths(current)
                if path:
                    pattern_base.append((path, current.count))
                current = current.next

            # If this action appears frequently enough, add it to patterns
            total_count = sum(count for _, count in pattern_base)
            if total_count >= min_support:
                patterns.append((action, total_count))

        return sorted(patterns, key=lambda x: x[1], reverse=True)

# Create and populate the FP-tree
fp_tree = FPTree()
fp_tree.build_tree(pruned_action_table)

# Print tree structure
fp_tree.print_tree()

# Get frequent patterns with minimum support of 2
frequent_patterns = fp_tree.get_frequent_patterns(min_support=7000)
print("\nFrequent Patterns:")
for pattern, support in frequent_patterns:
    print(f"Pattern: {pattern}, Support: {support}")
# Out:
# Streaming output truncated to the last 5000 lines.
#       ('A11', 2, 0) (count: 1)
#       ('A3', 'medium', 'high') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A8', 'low', 'medium') (count: 2)
#         ('A11', 2, 0) (count: 1)
#       ('A3', 'low', 'high') (count: 4)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A11', 3, 0) (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#         ('A11', 2, 0) (count: 1)
#         ('A11', 11, 0) (count: 1)
#           ('A13', 's', 'g') (count: 1)
#       ('A8', 'medium', 'high') (count: 2)
#         ('A11', 2, 0) (count: 2)
#     ('A2', 'medium', 'low') (count: 79)
#       ('A3', 'low', 'high') (count: 7)
#         ('A14', 'medium', 'low') (count: 3)
#           ('A11', 2, 0) (count: 2)
#           ('A11', 3, 0) (count: 1)
#             ('A7', 'bb', 'v') (count: 1)
#         ('A8', 'low', 'medium') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A7', 'bb', 'v') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A14', 'medium', 'low') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A14', 'high', 'low') (count: 8)
#         ('A3', 'medium', 'high') (count: 7)
#           ('A11', 3, 0) (count: 1)
#           ('A11', 2, 0) (count: 2)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A8', 'low', 'medium') (count: 3)
#             ('A11', 2, 0) (count: 3)
#         ('A8', 'low', 'medium') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A5', 'p', 'g') (count: 10)
#         ('A4', 'y', 'u') (count: 10)
#           ('A14', 'medium', 'high') (count: 1)
#             ('A3', 'low', 'high') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#                 ('A11', 3, 0) (count: 1)
#           ('A14', 'medium', 'low') (count: 2)
#             ('A11', 2, 0) (count: 1)
#           ('A3', 'low', 'high') (count: 2)
#             ('A14', 'medium', 'low') (count: 1)
#               ('A7', 'bb', 'v') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A14', 'medium', 'low') (count: 1)
#                 ('A7', 'bb', 'v') (count: 1)
#           ('A8', 'low', 'medium') (count: 4)
#             ('A14', 'medium', 'low') (count: 3)
#               ('A11', 2, 0) (count: 3)
#             ('A11', 2, 0) (count: 1)
#           ('A11', 1, 0) (count: 1)
#             ('A14', 'medium', 'low') (count: 1)
#       ('A3', 'low', 'medium') (count: 2)
#         ('A14', 'medium', 'high') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 3, 0) (count: 1)
#         ('A11', 1, 0) (count: 1)
#       ('A7', 'v', 'h') (count: 3)
#         ('A14', 'medium', 'high') (count: 1)
#           ('A3', 'low', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#                 ('A6', 'q', 'c') (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A13', 'g', 's') (count: 10)
#         ('A14', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A11', 1, 0) (count: 4)
#           ('A8', 'low', 'medium') (count: 2)
#           ('A7', 'h', 'ff') (count: 1)
#         ('A3', 'medium', 'high') (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A11', 5, 0) (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A14', 'high', 'low') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A5', 'p', 'g') (count: 1)
#           ('A4', 'y', 'u') (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#               ('A11', 2, 0) (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A11', 1, 0) (count: 32)
#         ('A14', 'high', 'low') (count: 16)
#           ('A7', 'v', 'h') (count: 2)
#             ('A3', 'low', 'high') (count: 2)
#               ('A8', 'low', 'medium') (count: 2)
#           ('A3', 'low', 'high') (count: 6)
#             ('A8', 'low', 'medium') (count: 4)
#           ('A3', 'medium', 'high') (count: 2)
#             ('A8', 'medium', 'high') (count: 1)
#         ('A7', 'v', 'h') (count: 3)
#           ('A8', 'low', 'medium') (count: 2)
#           ('A3', 'medium', 'high') (count: 1)
#         ('A3', 'low', 'high') (count: 7)
#           ('A8', 'low', 'medium') (count: 3)
#         ('A3', 'medium', 'high') (count: 3)
#           ('A8', 'low', 'medium') (count: 1)
#       ('A3', 'medium', 'high') (count: 6)
#         ('A8', 'low', 'medium') (count: 4)
#           ('A14', 'medium', 'low') (count: 3)
#             ('A11', 5, 0) (count: 3)
#           ('A11', 5, 0) (count: 1)
#         ('A14', 'medium', 'low') (count: 2)
#           ('A11', 5, 0) (count: 1)
#           ('A11', 2, 0) (count: 1)
#     ('A3', 'medium', 'low') (count: 87)
#       ('A2', 'low', 'high') (count: 2)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A7', 'v', 'bb') (count: 1)
#             ('A11', 2, 0) (count: 1)
#               ('A6', 'q', 'c') (count: 1)
#         ('A14', 'medium', 'high') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#       ('A2', 'low', 'medium') (count: 11)
#         ('A7', 'v', 'h') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A11', 1, 0) (count: 7)
#           ('A7', 'v', 'h') (count: 2)
#             ('A8', 'low', 'medium') (count: 1)
#           ('A14', 'medium', 'high') (count: 3)
#             ('A8', 'low', 'medium') (count: 2)
#         ('A5', 'p', 'g') (count: 1)
#           ('A4', 'y', 'u') (count: 1)
#             ('A11', 1, 0) (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A14', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A2', 'medium', 'high') (count: 11)
#         ('A7', 'v', 'h') (count: 3)
#           ('A11', 3, 0) (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A14', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A14', 'medium', 'low') (count: 3)
#           ('A11', 2, 0) (count: 1)
#           ('A11', 5, 0) (count: 2)
#         ('A11', 2, 0) (count: 2)
#         ('A14', 'medium', 'high') (count: 2)
#           ('A11', 5, 0) (count: 2)
#         ('A11', 5, 0) (count: 1)
#       ('A14', 'high', 'low') (count: 5)
#         ('A7', 'v', 'bb') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A7', 'v', 'h') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A2', 'medium', 'high') (count: 2)
#           ('A11', 2, 0) (count: 2)
#         ('A8', 'low', 'medium') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A7', 'v', 'h') (count: 2)
#         ('A11', 2, 0) (count: 2)
#       ('A11', 2, 0) (count: 5)
#       ('A2', 'medium', 'low') (count: 23)
#         ('A13', 'g', 's') (count: 9)
#           ('A14', 'medium', 'high') (count: 2)
#             ('A11', 2, 0) (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#               ('A11', 5, 0) (count: 1)
#           ('A14', 'high', 'low') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A11', 1, 0) (count: 3)
#             ('A7', 'v', 'ff') (count: 1)
#             ('A14', 'high', 'low') (count: 2)
#               ('A8', 'medium', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A14', 'high', 'low') (count: 1)
#                 ('A11', 2, 0) (count: 1)
#                   ('A6', 'q', 'c') (count: 1)
#         ('A14', 'high', 'low') (count: 4)
#           ('A7', 'v', 'h') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A11', 2, 0) (count: 3)
#         ('A8', 'low', 'medium') (count: 2)
#           ('A11', 2, 0) (count: 1)
#           ('A11', 5, 0) (count: 1)
#         ('A14', 'medium', 'low') (count: 3)
#           ('A11', 5, 0) (count: 3)
#         ('A11', 5, 0) (count: 2)
#         ('A14', 'medium', 'high') (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A11', 5, 0) (count: 1)
#         ('A7', 'v', 'h') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A11', 1, 0) (count: 1)
#           ('A14', 'high', 'low') (count: 1)
#             ('A7', 'v', 'h') (count: 1)
#       ('A11', 1, 0) (count: 18)
#         ('A2', 'low', 'high') (count: 7)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A7', 'v', 'bb') (count: 1)
#           ('A7', 'v', 'bb') (count: 1)
#           ('A7', 'v', 'h') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A2', 'medium', 'high') (count: 4)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A7', 'v', 'bb') (count: 1)
#           ('A7', 'v', 'h') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#           ('A7', 'v', 'bb') (count: 1)
#         ('A7', 'v', 'h') (count: 1)
#         ('A14', 'high', 'low') (count: 1)
#           ('A2', 'medium', 'high') (count: 1)
#             ('A7', 'v', 'bb') (count: 1)
#       ('A8', 'low', 'medium') (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#           ('A11', 5, 0) (count: 1)
#       ('A14', 'medium', 'high') (count: 1)
#         ('A11', 5, 0) (count: 1)
#       ('A5', 'p', 'g') (count: 3)
#         ('A4', 'y', 'u') (count: 3)
#           ('A11', 1, 0) (count: 2)
#             ('A14', 'high', 'low') (count: 1)
#               ('A7', 'v', 'h') (count: 1)
#             ('A2', 'low', 'high') (count: 1)
#               ('A7', 'v', 'h') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#           ('A2', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#       ('A13', 'g', 's') (count: 2)
#         ('A5', 'p', 'g') (count: 1)
#           ('A4', 'y', 'u') (count: 1)
#             ('A11', 1, 0) (count: 1)
#               ('A14', 'high', 'low') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A11', 2, 0) (count: 1)
#       ('A8', 'medium', 'high') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A14', 'medium', 'low') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A11', 6, 0) (count: 1)
#     ('A3', 'medium', 'high') (count: 9)
#       ('A11', 2, 0) (count: 3)
#       ('A11', 3, 0) (count: 1)
#       ('A8', 'medium', 'high') (count: 2)
#         ('A11', 2, 0) (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A14', 'medium', 'low') (count: 2)
#         ('A11', 5, 0) (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A8', 'low', 'medium') (count: 1)
#         ('A11', 6, 0) (count: 1)
#     ('A14', 'medium', 'high') (count: 9)
#       ('A11', 2, 0) (count: 3)
#       ('A11', 3, 0) (count: 1)
#       ('A8', 'low', 'medium') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A11', 5, 0) (count: 1)
#       ('A3', 'low', 'high') (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A3', 'medium', 'high') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A7', 'bb', 'v') (count: 1)
#     ('A7', 'h', 'v') (count: 103)
#       ('A14', 'low', 'high') (count: 5)
#         ('A5', 'p', 'g') (count: 2)
#           ('A4', 'y', 'u') (count: 2)
#             ('A11', 2, 0) (count: 1)
#             ('A3', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#         ('A13', 'g', 's') (count: 1)
#           ('A3', 'low', 'medium') (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#               ('A11', 3, 0) (count: 1)
#         ('A11', 3, 0) (count: 1)
#         ('A8', 'low', 'medium') (count: 1)
#           ('A11', 3, 0) (count: 1)
#       ('A2', 'medium', 'high') (count: 8)
#         ('A11', 2, 0) (count: 2)
#         ('A11', 3, 0) (count: 1)
#         ('A3', 'low', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A8', 'low', 'medium') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A14', 'medium', 'low') (count: 2)
#         ('A14', 'medium', 'high') (count: 1)
#       ('A8', 'high', 'medium') (count: 14)
#         ('A14', 'low', 'high') (count: 2)
#           ('A3', 'medium', 'low') (count: 2)
#             ('A5', 'p', 'g') (count: 1)
#               ('A4', 'y', 'u') (count: 1)
#                 ('A11', 2, 0) (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A2', 'medium', 'low') (count: 3)
#           ('A5', 'p', 'g') (count: 2)
#             ('A4', 'y', 'u') (count: 2)
#               ('A3', 'medium', 'high') (count: 1)
#                 ('A11', 2, 0) (count: 1)
#               ('A14', 'high', 'low') (count: 1)
#                 ('A3', 'medium', 'high') (count: 1)
#                   ('A11', 2, 0) (count: 1)
#           ('A11', 1, 0) (count: 1)
#             ('A14', 'high', 'low') (count: 1)
#               ('A3', 'medium', 'high') (count: 1)
#         ('A2', 'high', 'low') (count: 2)
#           ('A14', 'high', 'low') (count: 1)
#             ('A11', 7, 0) (count: 1)
#           ('A11', 3, 0) (count: 1)
#         ('A11', 3, 0) (count: 1)
#         ('A3', 'medium', 'low') (count: 5)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A11', 2, 0) (count: 1)
#           ('A2', 'medium', 'high') (count: 2)
#             ('A11', 2, 0) (count: 2)
#               ('A6', 'q', 'c') (count: 1)
#           ('A11', 2, 0) (count: 1)
#           ('A11', 1, 0) (count: 1)
#         ('A14', 'high', 'medium') (count: 1)
#           ('A2', 'medium', 'low') (count: 1)
#             ('A3', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#       ('A13', 'g', 's') (count: 8)
#         ('A5', 'p', 'g') (count: 2)
#           ('A4', 'y', 'u') (count: 2)
#             ('A3', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#             ('A14', 'high', 'low') (count: 1)
#               ('A3', 'medium', 'high') (count: 1)
#                 ('A11', 2, 0) (count: 1)
#         ('A3', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A11', 1, 0) (count: 3)
#           ('A8', 'low', 'medium') (count: 1)
#           ('A2', 'low', 'high') (count: 1)
#           ('A14', 'high', 'low') (count: 1)
#             ('A3', 'medium', 'high') (count: 1)
#         ('A14', 'high', 'low') (count: 2)
#           ('A3', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A3', 'low', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#       ('A2', 'medium', 'low') (count: 10)
#         ('A5', 'p', 'g') (count: 2)
#           ('A4', 'y', 'u') (count: 2)
#             ('A3', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#             ('A14', 'high', 'low') (count: 1)
#               ('A3', 'medium', 'high') (count: 1)
#                 ('A11', 2, 0) (count: 1)
#                   ('A6', 'q', 'c') (count: 1)
#         ('A3', 'low', 'high') (count: 2)
#           ('A11', 3, 0) (count: 2)
#         ('A3', 'low', 'medium') (count: 1)
#           ('A11', 3, 0) (count: 1)
#         ('A14', 'high', 'low') (count: 2)
#           ('A3', 'low', 'high') (count: 2)
#             ('A8', 'low', 'medium') (count: 1)
#               ('A11', 2, 0) (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A11', 1, 0) (count: 2)
#           ('A14', 'high', 'low') (count: 2)
#             ('A3', 'low', 'high') (count: 1)
#               ('A8', 'low', 'medium') (count: 1)
#             ('A3', 'medium', 'high') (count: 1)
#         ('A8', 'low', 'medium') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#       ('A5', 'p', 'g') (count: 6)
#         ('A4', 'y', 'u') (count: 6)
#           ('A11', 2, 0) (count: 2)
#           ('A3', 'low', 'high') (count: 2)
#             ('A14', 'medium', 'low') (count: 1)
#               ('A11', 3, 0) (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A14', 'medium', 'low') (count: 1)
#                 ('A11', 3, 0) (count: 1)
#           ('A3', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A14', 'high', 'low') (count: 1)
#             ('A11', 2, 0) (count: 1)
#       ('A2', 'low', 'medium') (count: 8)
#         ('A5', 'p', 'g') (count: 4)
#           ('A4', 'y', 'u') (count: 4)
#             ('A3', 'low', 'medium') (count: 2)
#               ('A14', 'medium', 'high') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#                   ('A11', 3, 0) (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#                 ('A14', 'medium', 'low') (count: 1)
#                   ('A11', 3, 0) (count: 1)
#             ('A14', 'medium', 'high') (count: 2)
#               ('A11', 3, 0) (count: 1)
#               ('A3', 'low', 'high') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#                   ('A11', 3, 0) (count: 1)
#         ('A14', 'medium', 'high') (count: 1)
#           ('A11', 3, 0) (count: 1)
#         ('A13', 'g', 's') (count: 2)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A3', 'low', 'high') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#                   ('A14', 'medium', 'low') (count: 1)
#                     ('A11', 3, 0) (count: 1)
#           ('A3', 'low', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A14', 'medium', 'low') (count: 1)
#                 ('A11', 3, 0) (count: 1)
#         ('A11', 1, 0) (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#       ('A3', 'low', 'medium') (count: 7)
#         ('A2', 'low', 'high') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A14', 'medium', 'low') (count: 1)
#               ('A11', 3, 0) (count: 1)
#         ('A11', 2, 0) (count: 1)
#         ('A2', 'medium', 'high') (count: 4)
#           ('A11', 2, 0) (count: 4)
#         ('A14', 'high', 'low') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A8', 'medium', 'low') (count: 5)
#         ('A5', 'p', 'g') (count: 5)
#           ('A4', 'y', 'u') (count: 5)
#             ('A3', 'low', 'medium') (count: 4)
#               ('A2', 'low', 'high') (count: 4)
#                 ('A14', 'medium', 'high') (count: 4)
#                   ('A11', 3, 0) (count: 4)
#             ('A2', 'low', 'high') (count: 1)
#               ('A14', 'medium', 'high') (count: 1)
#                 ('A11', 3, 0) (count: 1)
#       ('A3', 'low', 'high') (count: 2)
#         ('A11', 3, 0) (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A3', 'high', 'medium') (count: 6)
#         ('A2', 'high', 'medium') (count: 2)
#           ('A11', 7, 0) (count: 1)
#           ('A14', 'high', 'low') (count: 1)
#             ('A11', 7, 0) (count: 1)
#         ('A13', 'g', 's') (count: 4)
#           ('A11', 1, 0) (count: 4)
#             ('A2', 'low', 'high') (count: 2)
#               ('A14', 'medium', 'high') (count: 1)
#               ('A14', 'medium', 'low') (count: 1)
#             ('A14', 'high', 'low') (count: 1)
#       ('A2', 'high', 'medium') (count: 3)
#         ('A13', 'g', 's') (count: 1)
#           ('A14', 'high', 'low') (count: 1)
#             ('A11', 7, 0) (count: 1)
#         ('A11', 7, 0) (count: 1)
#         ('A11', 1, 0) (count: 1)
#           ('A14', 'high', 'low') (count: 1)
#       ('A2', 'high', 'low') (count: 5)
#         ('A14', 'high', 'low') (count: 1)
#           ('A11', 7, 0) (count: 1)
#             ('A6', 'q', 'c') (count: 1)
#         ('A14', 'high', 'medium') (count: 2)
#           ('A13', 'g', 's') (count: 1)
#             ('A11', 1, 0) (count: 1)
#               ('A8', 'low', 'medium') (count: 1)
#           ('A11', 1, 0) (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#         ('A11', 1, 0) (count: 2)
#           ('A14', 'high', 'low') (count: 2)
#             ('A8', 'low', 'medium') (count: 2)
#       ('A11', 1, 0) (count: 11)
#         ('A2', 'low', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A8', 'low', 'medium') (count: 3)
#           ('A14', 'medium', 'low') (count: 2)
#         ('A14', 'high', 'low') (count: 4)
#           ('A2', 'medium', 'high') (count: 3)
#             ('A3', 'low', 'high') (count: 3)
#               ('A8', 'low', 'medium') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A3', 'low', 'high') (count: 1)
#         ('A3', 'medium', 'high') (count: 1)
#       ('A11', 3, 0) (count: 2)
#       ('A14', 'high', 'medium') (count: 1)
#         ('A13', 'g', 's') (count: 1)
#           ('A11', 1, 0) (count: 1)
#       ('A14', 'high', 'low') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A8', 'low', 'medium') (count: 1)
#         ('A11', 2, 0) (count: 1)
#     ('A2', 'low', 'high') (count: 35)
#       ('A3', 'low', 'high') (count: 7)
#         ('A14', 'medium', 'low') (count: 2)
#           ('A11', 5, 0) (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A8', 'medium', 'high') (count: 4)
#           ('A14', 'medium', 'low') (count: 4)
#             ('A11', 5, 0) (count: 2)
#             ('A11', 2, 0) (count: 2)
#         ('A11', 6, 0) (count: 1)
#       ('A7', 'v', 'h') (count: 9)
#         ('A3', 'low', 'high') (count: 2)
#           ('A8', 'medium', 'high') (count: 2)
#             ('A14', 'medium', 'low') (count: 2)
#               ('A11', 5, 0) (count: 1)
#               ('A11', 2, 0) (count: 1)
#         ('A14', 'medium', 'high') (count: 2)
#           ('A11', 2, 0) (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A8', 'medium', 'high') (count: 10)
#         ('A14', 'medium', 'low') (count: 6)
#           ('A7', 'v', 'bb') (count: 3)
#             ('A11', 5, 0) (count: 1)
#             ('A6', 'q', 'c') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A11', 2, 0) (count: 3)
#         ('A7', 'v', 'bb') (count: 1)
#           ('A11', 11, 0) (count: 1)
#             ('A13', 's', 'g') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A11', 2, 0) (count: 1)
#       ('A14', 'medium', 'high') (count: 3)
#         ('A8', 'medium', 'high') (count: 2)
#           ('A11', 2, 0) (count: 1)
#         ('A3', 'medium', 'high') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#       ('A11', 3, 0) (count: 2)
#       ('A3', 'medium', 'high') (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A11', 2, 0) (count: 1)
#     ('A3', 'low', 'high') (count: 10)
#       ('A14', 'medium', 'low') (count: 4)
#         ('A11', 5, 0) (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A11', 2, 0) (count: 1)
#       ('A11', 11, 0) (count: 2)
#         ('A13', 's', 'g') (count: 2)
#       ('A8', 'low', 'medium') (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#       ('A8', 'medium', 'high') (count: 1)
#     ('A11', 3, 0) (count: 3)
#     ('A14', 'high', 'medium') (count: 92)
#       ('A3', 'medium', 'low') (count: 16)
#         ('A7', 'v', 'h') (count: 2)
#           ('A11', 3, 0) (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A11', 2, 0) (count: 1)
#         ('A2', 'medium', 'low') (count: 7)
#           ('A7', 'v', 'h') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#           ('A11', 2, 0) (count: 2)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A11', 2, 0) (count: 1)
#                 ('A6', 'q', 'c') (count: 1)
#           ('A11', 1, 0) (count: 2)
#             ('A7', 'v', 'h') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A2', 'low', 'medium') (count: 1)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A11', 1, 0) (count: 1)
#                 ('A7', 'v', 'h') (count: 1)
#                   ('A8', 'medium', 'high') (count: 1)
#         ('A5', 'p', 'g') (count: 2)
#           ('A4', 'y', 'u') (count: 2)
#             ('A11', 1, 0) (count: 1)
#               ('A7', 'v', 'h') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A11', 1, 0) (count: 2)
#           ('A7', 'v', 'h') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#       ('A2', 'medium', 'high') (count: 3)
#         ('A7', 'v', 'h') (count: 2)
#           ('A11', 3, 0) (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A2', 'medium', 'low') (count: 14)
#         ('A13', 'g', 's') (count: 3)
#           ('A11', 1, 0) (count: 2)
#             ('A3', 'low', 'high') (count: 2)
#               ('A8', 'low', 'medium') (count: 2)
#           ('A3', 'medium', 'high') (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#               ('A11', 2, 0) (count: 1)
#         ('A11', 1, 0) (count: 8)
#           ('A8', 'low', 'medium') (count: 2)
#           ('A3', 'low', 'high') (count: 2)
#             ('A8', 'low', 'medium') (count: 2)
#         ('A3', 'medium', 'high') (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A11', 2, 0) (count: 1)
#         ('A3', 'low', 'medium') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A3', 'low', 'medium') (count: 9)
#         ('A11', 1, 0) (count: 5)
#           ('A2', 'medium', 'high') (count: 2)
#             ('A7', 'v', 'bb') (count: 2)
#           ('A7', 'v', 'h') (count: 1)
#           ('A2', 'low', 'high') (count: 2)
#             ('A7', 'v', 'bb') (count: 1)
#             ('A7', 'v', 'h') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A7', 'v', 'bb') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A2', 'low', 'high') (count: 2)
#           ('A11', 3, 0) (count: 1)
#           ('A7', 'v', 'bb') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A11', 1, 0) (count: 14)
#         ('A2', 'medium', 'high') (count: 4)
#           ('A7', 'v', 'h') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#         ('A3', 'low', 'high') (count: 2)
#           ('A8', 'medium', 'high') (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#         ('A3', 'medium', 'high') (count: 1)
#         ('A2', 'low', 'high') (count: 1)
#         ('A8', 'low', 'medium') (count: 2)
#         ('A7', 'v', 'h') (count: 2)
#           ('A8', 'medium', 'high') (count: 1)
#           ('A3', 'medium', 'high') (count: 1)
#       ('A13', 'g', 's') (count: 11)
#         ('A11', 1, 0) (count: 4)
#           ('A2', 'medium', 'high') (count: 2)
#             ('A3', 'low', 'high') (count: 2)
#           ('A3', 'low', 'high') (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#           ('A2', 'low', 'high') (count: 1)
#             ('A3', 'low', 'high') (count: 1)
#         ('A3', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A3', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A3', 'low', 'high') (count: 3)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#           ('A8', 'low', 'medium') (count: 2)
#             ('A11', 3, 0) (count: 1)
#         ('A2', 'low', 'high') (count: 2)
#           ('A3', 'low', 'high') (count: 2)
#             ('A11', 3, 0) (count: 1)
#       ('A7', 'v', 'bb') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A7', 'v', 'h') (count: 1)
#         ('A3', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A2', 'low', 'medium') (count: 8)
#         ('A7', 'v', 'h') (count: 2)
#           ('A11', 2, 0) (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A11', 6, 0) (count: 1)
#         ('A5', 'p', 'g') (count: 2)
#           ('A4', 'y', 'u') (count: 2)
#             ('A11', 1, 0) (count: 2)
#               ('A3', 'low', 'high') (count: 1)
#               ('A7', 'v', 'h') (count: 1)
#                 ('A3', 'medium', 'high') (count: 1)
#         ('A11', 1, 0) (count: 4)
#           ('A7', 'v', 'h') (count: 4)
#             ('A3', 'medium', 'high') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#             ('A3', 'low', 'high') (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#       ('A11', 3, 0) (count: 2)
#       ('A2', 'low', 'high') (count: 2)
#         ('A11', 3, 0) (count: 1)
#       ('A8', 'low', 'medium') (count: 2)
#         ('A11', 3, 0) (count: 1)
#       ('A3', 'low', 'high') (count: 3)
#         ('A8', 'low', 'medium') (count: 3)
#           ('A11', 3, 0) (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A5', 'p', 'g') (count: 2)
#         ('A4', 'y', 'u') (count: 2)
#           ('A11', 1, 0) (count: 1)
#             ('A2', 'low', 'high') (count: 1)
#               ('A7', 'v', 'h') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#           ('A2', 'medium', 'high') (count: 1)
#             ('A11', 2, 0) (count: 1)
#       ('A3', 'medium', 'high') (count: 1)
#         ('A11', 2, 0) (count: 1)
#       ('A11', 2, 0) (count: 1)
#     ('A14', 'high', 'low') (count: 48)
#       ('A2', 'medium', 'high') (count: 9)
#         ('A7', 'v', 'h') (count: 6)
#           ('A11', 3, 0) (count: 2)
#           ('A3', 'medium', 'high') (count: 2)
#             ('A11', 3, 0) (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#           ('A8', 'medium', 'high') (count: 2)
#             ('A11', 2, 0) (count: 2)
#         ('A3', 'medium', 'high') (count: 1)
#           ('A11', 2, 0) (count: 1)
#         ('A3', 'low', 'high') (count: 2)
#           ('A11', 2, 0) (count: 2)
#             ('A7', 'h', 'ff') (count: 1)
#       ('A11', 3, 0) (count: 4)
#       ('A11', 7, 0) (count: 1)
#       ('A3', 'medium', 'high') (count: 2)
#         ('A11', 2, 0) (count: 2)
#       ('A8', 'medium', 'high') (count: 2)
#         ('A11', 2, 0) (count: 1)
#         ('A7', 'v', 'bb') (count: 1)
#           ('A11', 2, 0) (count: 1)
#       ('A2', 'low', 'high') (count: 16)
#         ('A3', 'low', 'high') (count: 8)
#           ('A11', 2, 0) (count: 1)
#           ('A8', 'medium', 'high') (count: 2)
#             ('A11', 2, 0) (count: 2)
#           ('A11', 3, 0) (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A11', 6, 0) (count: 1)
#           ('A11', 6, 0) (count: 2)
#         ('A7', 'v', 'h') (count: 3)
#           ('A3', 'low', 'high') (count: 2)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A11', 2, 0) (count: 1)
#             ('A11', 6, 0) (count: 1)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A7', 'v', 'bb') (count: 1)
#             ('A11', 2, 0) (count: 1)
#         ('A11', 3, 0) (count: 2)
#         ('A7', 'v', 'bb') (count: 1)
#         ('A11', 6, 0) (count: 1)
#           ('A7', 'v', 'bb') (count: 1)
#       ('A3', 'low', 'high') (count: 9)
#         ('A11', 2, 0) (count: 1)
#         ('A8', 'low', 'medium') (count: 6)
#           ('A11', 3, 0) (count: 3)
#           ('A11', 6, 0) (count: 1)
#         ('A11', 3, 0) (count: 1)
#       ('A7', 'v', 'h') (count: 1)
#         ('A3', 'low', 'high') (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#       ('A11', 2, 0) (count: 1)
#     ('A11', 7, 0) (count: 1)
#     ('A8', 'low', 'medium') (count: 4)
#       ('A11', 2, 0) (count: 3)
#       ('A11', 3, 0) (count: 1)
#     ('A11', 2, 0) (count: 2)
#     ('A8', 'medium', 'high') (count: 3)
#       ('A11', 2, 0) (count: 2)
#       ('A14', 'medium', 'low') (count: 1)
#         ('A7', 'bb', 'v') (count: 1)
#           ('A11', 2, 0) (count: 1)
#     ('A14', 'medium', 'low') (count: 4)
#       ('A11', 2, 0) (count: 2)
#       ('A7', 'bb', 'v') (count: 1)
#         ('A11', 2, 0) (count: 1)
#     ('A11', 6, 0) (count: 1)
#   ('A2', 'low', 'medium') (count: 1496)
#     ('A8', 'medium', 'high') (count: 20)
#       ('A6', 'q', 'c') (count: 1)
#       ('A14', 'medium', 'low') (count: 6)
#         ('A7', 'v', 'bb') (count: 1)
#           ('A6', 'q', 'c') (count: 1)
#         ('A6', 'q', 'c') (count: 1)
#       ('A7', 'v', 'bb') (count: 1)
#       ('A7', 'bb', 'v') (count: 1)
#     ('A7', 'v', 'h') (count: 167)
#       ('A8', 'medium', 'high') (count: 5)
#         ('A14', 'medium', 'low') (count: 2)
#           ('A6', 'q', 'c') (count: 1)
#       ('A14', 'medium', 'high') (count: 17)
#         ('A8', 'medium', 'high') (count: 3)
#         ('A3', 'low', 'high') (count: 2)
#           ('A8', 'medium', 'high') (count: 1)
#         ('A8', 'low', 'medium') (count: 4)
#           ('A6', 'q', 'c') (count: 1)
#         ('A13', 's', 'g') (count: 2)
#       ('A10', 'f', 't') (count: 111)
#         ('A14', 'medium', 'low') (count: 3)
#         ('A14', 'medium', 'high') (count: 40)
#           ('A8', 'medium', 'high') (count: 7)
#           ('A3', 'low', 'high') (count: 11)
#             ('A8', 'medium', 'high') (count: 5)
#               ('A13', 's', 'g') (count: 1)
#             ('A13', 's', 'g') (count: 1)
#           ('A8', 'low', 'medium') (count: 5)
#             ('A13', 's', 'g') (count: 1)
#           ('A3', 'medium', 'high') (count: 6)
#             ('A8', 'medium', 'high') (count: 3)
#         ('A3', 'low', 'high') (count: 27)
#           ('A8', 'medium', 'high') (count: 11)
#             ('A14', 'medium', 'low') (count: 5)
#               ('A13', 's', 'g') (count: 1)
#               ('A6', 'q', 'c') (count: 2)
#             ('A13', 's', 'g') (count: 4)
#           ('A14', 'medium', 'low') (count: 6)
#             ('A13', 's', 'g') (count: 1)
#             ('A6', 'q', 'c') (count: 1)
#           ('A13', 's', 'g') (count: 2)
#         ('A8', 'medium', 'high') (count: 14)
#           ('A14', 'medium', 'low') (count: 1)
#           ('A13', 's', 'g') (count: 5)
#         ('A3', 'medium', 'high') (count: 6)
#           ('A13', 's', 'g') (count: 1)
#           ('A14', 'medium', 'low') (count: 2)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A14', 'medium', 'low') (count: 1)
#         ('A13', 's', 'g') (count: 2)
#         ('A8', 'low', 'medium') (count: 7)
#           ('A14', 'medium', 'low') (count: 2)
#       ('A3', 'medium', 'high') (count: 7)
#         ('A8', 'medium', 'high') (count: 2)
#           ('A6', 'q', 'c') (count: 1)
#         ('A8', 'low', 'medium') (count: 1)
#       ('A14', 'medium', 'low') (count: 3)
#       ('A8', 'low', 'medium') (count: 10)
#         ('A14', 'medium', 'low') (count: 4)
#           ('A13', 's', 'g') (count: 1)
#         ('A6', 'q', 'c') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#       ('A3', 'low', 'high') (count: 8)
#         ('A14', 'medium', 'low') (count: 1)
#         ('A8', 'medium', 'high') (count: 4)
#           ('A14', 'medium', 'low') (count: 1)
#             ('A6', 'q', 'c') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#       ('A13', 's', 'g') (count: 1)
#     ('A14', 'medium', 'high') (count: 50)
#       ('A8', 'medium', 'high') (count: 14)
#         ('A6', 'q', 'c') (count: 1)
#       ('A7', 'v', 'bb') (count: 4)
#         ('A13', 's', 'g') (count: 1)
#         ('A6', 'q', 'c') (count: 1)
#       ('A3', 'low', 'high') (count: 6)
#         ('A8', 'low', 'medium') (count: 2)
#           ('A6', 'q', 'c') (count: 1)
#         ('A8', 'medium', 'high') (count: 3)
#       ('A8', 'low', 'medium') (count: 4)
#       ('A13', 's', 'g') (count: 1)
#       ('A3', 'medium', 'high') (count: 6)
#         ('A8', 'medium', 'high') (count: 3)
#         ('A8', 'low', 'medium') (count: 1)
#     ('A14', 'medium', 'low') (count: 6)
#       ('A6', 'q', 'c') (count: 2)
#     ('A5', 'p', 'g') (count: 516)
#       ('A4', 'y', 'u') (count: 516)
#         ('A7', 'v', 'h') (count: 70)
#           ('A14', 'medium', 'high') (count: 9)
#             ('A3', 'low', 'high') (count: 4)
#             ('A8', 'low', 'medium') (count: 2)
#           ('A3', 'low', 'high') (count: 5)
#             ('A14', 'medium', 'low') (count: 3)
#             ('A8', 'medium', 'high') (count: 1)
#           ('A10', 'f', 't') (count: 43)
#             ('A3', 'low', 'high') (count: 8)
#               ('A14', 'medium', 'low') (count: 5)
#                 ('A13', 's', 'g') (count: 1)
#               ('A8', 'medium', 'high') (count: 2)
#                 ('A13', 's', 'g') (count: 1)
#                 ('A14', 'medium', 'low') (count: 1)
#             ('A14', 'medium', 'high') (count: 22)
#               ('A8', 'low', 'medium') (count: 5)
#                 ('A13', 's', 'g') (count: 1)
#               ('A3', 'low', 'high') (count: 7)
#                 ('A13', 's', 'g') (count: 1)
#                 ('A8', 'medium', 'high') (count: 2)
#               ('A3', 'medium', 'high') (count: 2)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A14', 'medium', 'low') (count: 3)
#             ('A8', 'medium', 'high') (count: 4)
#               ('A13', 's', 'g') (count: 1)
#               ('A14', 'medium', 'low') (count: 1)
#             ('A3', 'medium', 'high') (count: 2)
#               ('A14', 'medium', 'low') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A8', 'low', 'medium') (count: 1)
#           ('A8', 'low', 'medium') (count: 6)
#             ('A14', 'medium', 'low') (count: 5)
#               ('A13', 's', 'g') (count: 1)
#           ('A8', 'medium', 'high') (count: 2)
#           ('A3', 'medium', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#           ('A14', 'medium', 'low') (count: 2)
#         ('A10', 'f', 't') (count: 197)
#           ('A3', 'low', 'high') (count: 51)
#             ('A8', 'medium', 'high') (count: 8)
#               ('A14', 'medium', 'low') (count: 4)
#                 ('A7', 'v', 'bb') (count: 2)
#             ('A14', 'medium', 'low') (count: 12)
#               ('A7', 'v', 'bb') (count: 5)
#                 ('A13', 's', 'g') (count: 1)
#               ('A13', 's', 'g') (count: 1)
#             ('A8', 'low', 'medium') (count: 8)
#               ('A14', 'medium', 'low') (count: 5)
#                 ('A13', 's', 'g') (count: 1)
#             ('A7', 'v', 'bb') (count: 1)
#             ('A13', 's', 'g') (count: 1)
#           ('A14', 'medium', 'high') (count: 68)
#             ('A8', 'medium', 'high') (count: 5)
#             ('A3', 'low', 'high') (count: 21)
#               ('A13', 's', 'g') (count: 3)
#               ('A8', 'medium', 'high') (count: 4)
#               ('A8', 'low', 'medium') (count: 1)
#             ('A3', 'medium', 'high') (count: 7)
#               ('A8', 'low', 'medium') (count: 1)
#             ('A13', 's', 'g') (count: 1)
#             ('A8', 'low', 'medium') (count: 3)
#           ('A8', 'low', 'medium') (count: 29)
#             ('A14', 'medium', 'low') (count: 12)
#               ('A13', 's', 'g') (count: 1)
#             ('A13', 's', 'g') (count: 1)
#             ('A7', 'bb', 'v') (count: 1)
#           ('A14', 'medium', 'low') (count: 11)
#             ('A7', 'v', 'bb') (count: 3)
#           ('A3', 'medium', 'high') (count: 12)
#             ('A14', 'medium', 'low') (count: 5)
#               ('A7', 'v', 'bb') (count: 1)
#             ('A8', 'low', 'medium') (count: 2)
#               ('A14', 'medium', 'low') (count: 1)
#           ('A8', 'medium', 'high') (count: 5)
#             ('A14', 'medium', 'low') (count: 1)
#             ('A13', 's', 'g') (count: 1)
#           ('A13', 's', 'g') (count: 5)
#           ('A7', 'bb', 'v') (count: 1)
#         ('A3', 'low', 'medium') (count: 131)
#           ('A7', 'v', 'h') (count: 49)
#             ('A10', 'f', 't') (count: 30)
#               ('A14', 'medium', 'high') (count: 14)
#                 ('A13', 's', 'g') (count: 2)
#                 ('A8', 'medium', 'high') (count: 3)
#               ('A8', 'low', 'medium') (count: 5)
#                 ('A13', 's', 'g') (count: 1)
#               ('A13', 's', 'g') (count: 2)
#               ('A8', 'medium', 'high') (count: 3)
#                 ('A13', 's', 'g') (count: 1)
#             ('A14', 'medium', 'high') (count: 13)
#               ('A13', 's', 'g') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A8', 'low', 'medium') (count: 2)
#           ('A10', 'f', 't') (count: 49)
#             ('A14', 'medium', 'high') (count: 9)
#               ('A8', 'medium', 'high') (count: 5)
#             ('A8', 'low', 'medium') (count: 12)
#               ('A14', 'medium', 'low') (count: 7)
#                 ('A13', 's', 'g') (count: 1)
#             ('A13', 's', 'g') (count: 3)
#             ('A8', 'medium', 'high') (count: 10)
#               ('A14', 'medium', 'low') (count: 2)
#               ('A13', 's', 'g') (count: 2)
#             ('A14', 'medium', 'low') (count: 1)
#           ('A14', 'medium', 'high') (count: 7)
#             ('A8', 'medium', 'high') (count: 3)
#             ('A8', 'low', 'medium') (count: 1)
#           ('A8', 'medium', 'high') (count: 5)
#             ('A14', 'medium', 'low') (count: 2)
#             ('A13', 's', 'g') (count: 1)
#           ('A8', 'low', 'medium') (count: 3)
#             ('A14', 'medium', 'low') (count: 2)
#           ('A14', 'high', 'low') (count: 6)
#             ('A10', 'f', 't') (count: 3)
#               ('A8', 'medium', 'high') (count: 1)
#                 ('A13', 's', 'g') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#               ('A13', 's', 'g') (count: 1)
#             ('A7', 'v', 'h') (count: 2)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A3', 'low', 'high') (count: 29)
#           ('A14', 'medium', 'low') (count: 11)
#             ('A7', 'v', 'bb') (count: 3)
#             ('A13', 's', 'g') (count: 1)
#           ('A8', 'low', 'medium') (count: 4)
#             ('A14', 'medium', 'low') (count: 2)
#           ('A8', 'medium', 'high') (count: 2)
#             ('A13', 's', 'g') (count: 1)
#             ('A14', 'medium', 'low') (count: 1)
#         ('A14', 'medium', 'high') (count: 33)
#           ('A3', 'low', 'high') (count: 12)
#             ('A8', 'medium', 'high') (count: 3)
#           ('A7', 'v', 'bb') (count: 5)
#             ('A13', 's', 'g') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#           ('A8', 'low', 'medium') (count: 3)
#           ('A3', 'medium', 'high') (count: 2)
#           ('A7', 'bb', 'v') (count: 1)
#         ('A14', 'high', 'low') (count: 24)
#           ('A10', 'f', 't') (count: 15)
#             ('A7', 'v', 'bb') (count: 1)
#               ('A6', 'q', 'c') (count: 1)
#             ('A3', 'low', 'high') (count: 8)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 3)
#           ('A8', 'low', 'medium') (count: 3)
#           ('A7', 'v', 'h') (count: 2)
#             ('A10', 'f', 't') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#                 ('A13', 's', 'g') (count: 1)
#             ('A3', 'low', 'high') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#           ('A3', 'low', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#           ('A8', 'medium', 'high') (count: 2)
#         ('A8', 'medium', 'high') (count: 5)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A8', 'low', 'medium') (count: 8)
#           ('A14', 'medium', 'low') (count: 2)
#         ('A14', 'medium', 'low') (count: 5)
#         ('A3', 'medium', 'high') (count: 4)
#           ('A8', 'low', 'medium') (count: 2)
#           ('A14', 'medium', 'low') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#     ('A3', 'low', 'medium') (count: 210)
#       ('A10', 'f', 't') (count: 68)
#         ('A8', 'medium', 'high') (count: 16)
#           ('A13', 's', 'g') (count: 8)
#           ('A6', 'q', 'c') (count: 2)
#         ('A14', 'medium', 'low') (count: 4)
#         ('A13', 's', 'g') (count: 9)
#         ('A8', 'low', 'medium') (count: 11)
#           ('A14', 'medium', 'low') (count: 4)
#             ('A13', 's', 'g') (count: 1)
#           ('A13', 's', 'g') (count: 2)
#           ('A6', 'q', 'c') (count: 1)
#         ('A14', 'medium', 'high') (count: 9)
#           ('A8', 'medium', 'high') (count: 2)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A6', 'q', 'c') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#         ('A7', 'v', 'bb') (count: 1)
#         ('A6', 'q', 'c') (count: 1)
#       ('A7', 'v', 'h') (count: 89)
#         ('A14', 'medium', 'high') (count: 13)
#           ('A8', 'medium', 'high') (count: 5)
#             ('A6', 'q', 'c') (count: 2)
#           ('A13', 's', 'g') (count: 2)
#           ('A8', 'low', 'medium') (count: 2)
#           ('A6', 'q', 'c') (count: 1)
#         ('A10', 'f', 't') (count: 58)
#           ('A14', 'medium', 'high') (count: 14)
#             ('A8', 'medium', 'high') (count: 6)
#             ('A13', 's', 'g') (count: 2)
#           ('A8', 'medium', 'high') (count: 7)
#             ('A13', 's', 'g') (count: 3)
#           ('A13', 's', 'g') (count: 6)
#           ('A8', 'low', 'medium') (count: 13)
#             ('A13', 's', 'g') (count: 2)
#             ('A14', 'medium', 'low') (count: 4)
#           ('A14', 'medium', 'low') (count: 4)
#             ('A13', 's', 'g') (count: 2)
#         ('A8', 'low', 'medium') (count: 2)
#           ('A14', 'medium', 'low') (count: 2)
#         ('A8', 'medium', 'high') (count: 2)
#       ('A14', 'medium', 'high') (count: 6)
#         ('A6', 'q', 'c') (count: 1)
#       ('A8', 'medium', 'high') (count: 9)
#         ('A13', 's', 'g') (count: 4)
#         ('A6', 'q', 'c') (count: 1)
#       ('A14', 'high', 'low') (count: 22)
#         ('A10', 'f', 't') (count: 10)
#           ('A8', 'medium', 'high') (count: 4)
#             ('A13', 's', 'g') (count: 3)
#           ('A13', 's', 'g') (count: 1)
#           ('A8', 'low', 'medium') (count: 3)
#         ('A8', 'medium', 'high') (count: 4)
#           ('A13', 's', 'g') (count: 3)
#         ('A13', 's', 'g') (count: 1)
#         ('A7', 'v', 'h') (count: 3)
#           ('A8', 'medium', 'high') (count: 1)
#           ('A10', 'f', 't') (count: 2)
#         ('A8', 'low', 'medium') (count: 3)
#       ('A8', 'low', 'medium') (count: 4)
#         ('A14', 'medium', 'low') (count: 2)
#       ('A13', 's', 'g') (count: 2)
#       ('A14', 'medium', 'low') (count: 1)
#     ('A10', 'f', 't') (count: 289)
#       ('A14', 'medium', 'high') (count: 80)
#         ('A3', 'low', 'high') (count: 26)
#           ('A8', 'medium', 'high') (count: 9)
#           ('A13', 's', 'g') (count: 4)
#             ('A6', 'q', 'c') (count: 1)
#           ('A8', 'low', 'medium') (count: 2)
#         ('A8', 'low', 'medium') (count: 7)
#         ('A8', 'medium', 'high') (count: 11)
#           ('A13', 's', 'g') (count: 1)
#         ('A13', 's', 'g') (count: 3)
#         ('A3', 'medium', 'high') (count: 12)
#           ('A8', 'low', 'medium') (count: 1)
#             ('A6', 'q', 'c') (count: 1)
#           ('A8', 'medium', 'high') (count: 4)
#         ('A6', 'q', 'c') (count: 1)
#       ('A14', 'medium', 'low') (count: 13)
#         ('A7', 'v', 'bb') (count: 2)
#         ('A13', 's', 'g') (count: 1)
#         ('A6', 'q', 'c') (count: 2)
#       ('A8', 'low', 'medium') (count: 35)
#         ('A14', 'medium', 'low') (count: 8)
#           ('A13', 's', 'g') (count: 1)
#           ('A6', 'q', 'c') (count: 1)
#         ('A13', 's', 'g') (count: 8)
#       ('A8', 'medium', 'high') (count: 28)
#         ('A14', 'medium', 'low') (count: 4)
#           ('A7', 'v', 'bb') (count: 1)
#         ('A13', 's', 'g') (count: 3)
#         ('A7', 'v', 'bb') (count: 3)
#       ('A3', 'low', 'high') (count: 56)
#         ('A8', 'medium', 'high') (count: 13)
#           ('A14', 'medium', 'low') (count: 10)
#             ('A7', 'v', 'bb') (count: 5)
#               ('A6', 'q', 'c') (count: 2)
#               ('A13', 's', 'g') (count: 1)
#             ('A6', 'q', 'c') (count: 2)
#             ('A13', 's', 'g') (count: 1)
#           ('A6', 'q', 'c') (count: 2)
#         ('A14', 'medium', 'low') (count: 15)
#           ('A7', 'v', 'bb') (count: 5)
#             ('A13', 's', 'g') (count: 1)
#             ('A6', 'q', 'c') (count: 2)
#           ('A13', 's', 'g') (count: 1)
#           ('A6', 'q', 'c') (count: 3)
#         ('A13', 's', 'g') (count: 3)
#         ('A8', 'low', 'medium') (count: 7)
#           ('A14', 'medium', 'low') (count: 4)
#             ('A13', 's', 'g') (count: 1)
#             ('A6', 'q', 'c') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#         ('A7', 'v', 'bb') (count: 2)
#           ('A13', 's', 'g') (count: 1)
#         ('A6', 'q', 'c') (count: 1)
#       ('A3', 'medium', 'high') (count: 21)
#         ('A7', 'v', 'bb') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#         ('A8', 'low', 'medium') (count: 3)
#           ('A13', 's', 'g') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A14', 'medium', 'low') (count: 6)
#           ('A7', 'v', 'bb') (count: 1)
# ...
#             ('A2', 'medium', 'high') (count: 1)
#               ('A3', 'medium', 'high') (count: 1)
#             ('A2', 'low', 'high') (count: 1)
#             ('A10', 'f', 't') (count: 1)
#       ('A14', 'medium', 'high') (count: 1)
#       ('A2', 'low', 'medium') (count: 1)
#         ('A5', 'p', 'g') (count: 1)
#           ('A4', 'y', 'u') (count: 1)
#             ('A14', 'medium', 'low') (count: 1)
#       ('A14', 'high', 'low') (count: 4)
#         ('A2', 'low', 'high') (count: 1)
#         ('A10', 'f', 't') (count: 1)
#         ('A2', 'medium', 'high') (count: 2)
#           ('A10', 'f', 't') (count: 1)
#       ('A14', 'high', 'medium') (count: 10)
#         ('A2', 'low', 'high') (count: 1)
#           ('A10', 'f', 't') (count: 1)
#         ('A10', 'f', 't') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A10', 'f', 't') (count: 1)
#         ('A2', 'medium', 'low') (count: 2)
#           ('A10', 'f', 't') (count: 1)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A10', 'f', 't') (count: 1)
#                 ('A3', 'medium', 'high') (count: 1)
#         ('A5', 'p', 'g') (count: 3)
#           ('A4', 'y', 'u') (count: 3)
#             ('A2', 'medium', 'high') (count: 1)
#               ('A10', 'f', 't') (count: 1)
#                 ('A3', 'medium', 'high') (count: 1)
#             ('A2', 'low', 'high') (count: 1)
#               ('A10', 'f', 't') (count: 1)
#             ('A10', 'f', 't') (count: 1)
#         ('A3', 'medium', 'low') (count: 2)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A2', 'medium', 'high') (count: 1)
#           ('A2', 'medium', 'low') (count: 1)
#             ('A5', 'p', 'g') (count: 1)
#               ('A4', 'y', 'u') (count: 1)
#       ('A2', 'medium', 'low') (count: 8)
#         ('A14', 'high', 'low') (count: 5)
#           ('A3', 'low', 'high') (count: 2)
#           ('A10', 'f', 't') (count: 1)
#         ('A3', 'low', 'medium') (count: 2)
#           ('A14', 'high', 'low') (count: 2)
#             ('A10', 'f', 't') (count: 1)
#         ('A5', 'p', 'g') (count: 1)
#           ('A4', 'y', 'u') (count: 1)
#             ('A14', 'high', 'low') (count: 1)
#               ('A10', 'f', 't') (count: 1)
#                 ('A3', 'medium', 'high') (count: 1)
#       ('A3', 'high', 'medium') (count: 9)
#         ('A2', 'medium', 'low') (count: 2)
#           ('A14', 'high', 'low') (count: 2)
#             ('A10', 'f', 't') (count: 1)
#         ('A2', 'low', 'high') (count: 1)
#           ('A10', 'f', 't') (count: 1)
#             ('A14', 'medium', 'high') (count: 1)
#         ('A5', 'p', 'g') (count: 5)
#           ('A4', 'y', 'u') (count: 5)
#             ('A2', 'low', 'high') (count: 5)
#               ('A14', 'medium', 'high') (count: 4)
#               ('A10', 'f', 't') (count: 1)
#                 ('A14', 'medium', 'high') (count: 1)
#         ('A14', 'high', 'low') (count: 1)
#           ('A2', 'low', 'high') (count: 1)
#             ('A10', 'f', 't') (count: 1)
#       ('A2', 'high', 'medium') (count: 1)
#         ('A3', 'low', 'medium') (count: 1)
#           ('A14', 'medium', 'high') (count: 1)
#       ('A3', 'medium', 'high') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#       ('A2', 'low', 'high') (count: 6)
#         ('A14', 'medium', 'high') (count: 5)
#           ('A3', 'medium', 'high') (count: 1)
#         ('A10', 'f', 't') (count: 1)
#           ('A14', 'medium', 'high') (count: 1)
#       ('A3', 'medium', 'low') (count: 9)
#         ('A2', 'low', 'medium') (count: 1)
#           ('A10', 'f', 't') (count: 1)
#             ('A14', 'medium', 'low') (count: 1)
#         ('A2', 'low', 'high') (count: 1)
#           ('A14', 'medium', 'high') (count: 1)
#         ('A10', 'f', 't') (count: 1)
#         ('A2', 'medium', 'low') (count: 3)
#           ('A5', 'p', 'g') (count: 3)
#             ('A4', 'y', 'u') (count: 3)
#               ('A14', 'high', 'low') (count: 3)
#         ('A5', 'p', 'g') (count: 1)
#           ('A4', 'y', 'u') (count: 1)
#             ('A10', 'f', 't') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A10', 'f', 't') (count: 1)
#         ('A13', 'g', 's') (count: 1)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A2', 'medium', 'high') (count: 1)
#                 ('A10', 'f', 't') (count: 1)
#     ('A2', 'low', 'high') (count: 39)
#       ('A14', 'medium', 'high') (count: 4)
#       ('A10', 'f', 't') (count: 28)
#         ('A8', 'medium', 'high') (count: 3)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A3', 'medium', 'high') (count: 5)
#           ('A8', 'medium', 'high') (count: 2)
#             ('A14', 'medium', 'low') (count: 2)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A14', 'medium', 'high') (count: 4)
#           ('A3', 'medium', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 1)
#           ('A3', 'low', 'high') (count: 2)
#         ('A14', 'medium', 'low') (count: 3)
#         ('A3', 'low', 'high') (count: 6)
#           ('A14', 'medium', 'low') (count: 3)
#           ('A8', 'low', 'medium') (count: 1)
#       ('A14', 'medium', 'low') (count: 3)
#       ('A8', 'low', 'medium') (count: 1)
#       ('A3', 'low', 'high') (count: 1)
#     ('A14', 'high', 'low') (count: 99)
#       ('A6', 'q', 'c') (count: 2)
#       ('A2', 'low', 'high') (count: 12)
#         ('A10', 'f', 't') (count: 12)
#           ('A8', 'medium', 'high') (count: 4)
#           ('A3', 'low', 'high') (count: 5)
#       ('A10', 'f', 't') (count: 28)
#         ('A8', 'medium', 'high') (count: 2)
#         ('A13', 's', 'g') (count: 2)
#         ('A6', 'q', 'c') (count: 1)
#         ('A3', 'medium', 'high') (count: 8)
#           ('A8', 'medium', 'high') (count: 3)
#             ('A13', 's', 'g') (count: 3)
#         ('A8', 'low', 'medium') (count: 3)
#         ('A3', 'low', 'high') (count: 2)
#           ('A8', 'low', 'medium') (count: 1)
#       ('A2', 'medium', 'high') (count: 38)
#         ('A10', 'f', 't') (count: 27)
#           ('A3', 'medium', 'high') (count: 8)
#             ('A13', 's', 'g') (count: 2)
#             ('A8', 'medium', 'high') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#           ('A8', 'medium', 'high') (count: 6)
#             ('A6', 'q', 'c') (count: 2)
#           ('A3', 'low', 'high') (count: 9)
#             ('A6', 'q', 'c') (count: 1)
#             ('A8', 'medium', 'high') (count: 3)
#             ('A13', 's', 'g') (count: 2)
#         ('A3', 'medium', 'high') (count: 4)
#         ('A8', 'medium', 'high') (count: 1)
#         ('A3', 'low', 'high') (count: 5)
#       ('A3', 'medium', 'high') (count: 4)
#         ('A13', 's', 'g') (count: 1)
#         ('A8', 'medium', 'high') (count: 2)
#           ('A13', 's', 'g') (count: 2)
#       ('A13', 's', 'g') (count: 1)
#       ('A3', 'low', 'high') (count: 3)
#         ('A8', 'low', 'medium') (count: 1)
#       ('A8', 'medium', 'high') (count: 1)
#     ('A14', 'high', 'medium') (count: 160)
#       ('A13', 'g', 's') (count: 12)
#         ('A2', 'low', 'high') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#         ('A5', 'p', 'g') (count: 9)
#           ('A4', 'y', 'u') (count: 9)
#             ('A3', 'low', 'high') (count: 3)
#               ('A8', 'low', 'medium') (count: 3)
#             ('A2', 'low', 'high') (count: 4)
#               ('A3', 'low', 'high') (count: 3)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A2', 'medium', 'high') (count: 1)
#               ('A3', 'medium', 'high') (count: 1)
#                 ('A8', 'medium', 'high') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A8', 'medium', 'high') (count: 1)
#       ('A2', 'low', 'medium') (count: 22)
#         ('A10', 'f', 't') (count: 3)
#           ('A8', 'medium', 'high') (count: 1)
#           ('A3', 'low', 'high') (count: 2)
#             ('A8', 'low', 'medium') (count: 1)
#         ('A5', 'p', 'g') (count: 14)
#           ('A4', 'y', 'u') (count: 14)
#             ('A8', 'low', 'medium') (count: 1)
#             ('A10', 'f', 't') (count: 7)
#               ('A8', 'low', 'medium') (count: 3)
#               ('A3', 'low', 'high') (count: 3)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A3', 'low', 'medium') (count: 6)
#               ('A10', 'f', 't') (count: 6)
#         ('A3', 'low', 'medium') (count: 4)
#           ('A10', 'f', 't') (count: 4)
#         ('A8', 'low', 'medium') (count: 1)
#       ('A2', 'low', 'high') (count: 6)
#         ('A10', 'f', 't') (count: 6)
#           ('A8', 'low', 'medium') (count: 3)
#           ('A3', 'low', 'high') (count: 2)
#             ('A8', 'low', 'medium') (count: 2)
#       ('A10', 'f', 't') (count: 19)
#         ('A3', 'medium', 'high') (count: 4)
#           ('A13', 's', 'g') (count: 2)
#           ('A8', 'medium', 'high') (count: 1)
#             ('A13', 's', 'g') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#         ('A3', 'low', 'high') (count: 5)
#           ('A8', 'low', 'medium') (count: 2)
#             ('A13', 's', 'g') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#         ('A8', 'medium', 'high') (count: 2)
#       ('A5', 'p', 'g') (count: 51)
#         ('A4', 'y', 'u') (count: 51)
#           ('A10', 'f', 't') (count: 17)
#             ('A3', 'low', 'high') (count: 9)
#               ('A8', 'low', 'medium') (count: 6)
#             ('A3', 'medium', 'high') (count: 1)
#               ('A8', 'medium', 'high') (count: 1)
#             ('A8', 'medium', 'high') (count: 2)
#           ('A2', 'low', 'high') (count: 10)
#             ('A10', 'f', 't') (count: 7)
#               ('A3', 'low', 'high') (count: 6)
#                 ('A8', 'low', 'medium') (count: 3)
#           ('A3', 'low', 'medium') (count: 9)
#             ('A2', 'low', 'high') (count: 6)
#               ('A10', 'f', 't') (count: 6)
#                 ('A8', 'low', 'medium') (count: 3)
#             ('A10', 'f', 't') (count: 3)
#               ('A8', 'low', 'medium') (count: 3)
#           ('A8', 'low', 'medium') (count: 3)
#           ('A3', 'low', 'high') (count: 3)
#             ('A8', 'low', 'medium') (count: 3)
#           ('A3', 'medium', 'high') (count: 1)
#           ('A2', 'medium', 'high') (count: 3)
#             ('A10', 'f', 't') (count: 3)
#               ('A8', 'medium', 'high') (count: 1)
#               ('A3', 'medium', 'high') (count: 1)
#       ('A2', 'medium', 'low') (count: 20)
#         ('A10', 'f', 't') (count: 9)
#           ('A8', 'medium', 'high') (count: 3)
#           ('A3', 'medium', 'high') (count: 1)
#           ('A3', 'low', 'high') (count: 3)
#             ('A8', 'medium', 'high') (count: 3)
#         ('A3', 'low', 'medium') (count: 3)
#           ('A10', 'f', 't') (count: 2)
#             ('A8', 'low', 'medium') (count: 2)
#               ('A6', 'q', 'c') (count: 1)
#               ('A13', 's', 'g') (count: 1)
#           ('A8', 'low', 'medium') (count: 1)
#         ('A13', 'g', 's') (count: 2)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#               ('A3', 'medium', 'high') (count: 1)
#         ('A3', 'low', 'high') (count: 1)
#         ('A5', 'p', 'g') (count: 4)
#           ('A4', 'y', 'u') (count: 4)
#             ('A10', 'f', 't') (count: 3)
#               ('A3', 'medium', 'high') (count: 2)
#             ('A3', 'medium', 'high') (count: 1)
#       ('A2', 'medium', 'high') (count: 10)
#         ('A10', 'f', 't') (count: 6)
#           ('A3', 'low', 'high') (count: 4)
#             ('A8', 'low', 'medium') (count: 4)
#               ('A13', 's', 'g') (count: 2)
#           ('A3', 'medium', 'high') (count: 1)
#         ('A3', 'low', 'high') (count: 4)
#           ('A8', 'low', 'medium') (count: 3)
#       ('A3', 'low', 'medium') (count: 5)
#         ('A10', 'f', 't') (count: 4)
#           ('A8', 'low', 'medium') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#       ('A8', 'low', 'medium') (count: 1)
#       ('A3', 'low', 'high') (count: 4)
#         ('A8', 'low', 'medium') (count: 2)
#       ('A3', 'medium', 'high') (count: 1)
#       ('A3', 'medium', 'low') (count: 4)
#         ('A5', 'p', 'g') (count: 1)
#           ('A4', 'y', 'u') (count: 1)
#             ('A10', 'f', 't') (count: 1)
#         ('A2', 'medium', 'high') (count: 1)
#           ('A10', 'f', 't') (count: 1)
#         ('A2', 'medium', 'low') (count: 1)
#           ('A5', 'p', 'g') (count: 1)
#             ('A4', 'y', 'u') (count: 1)
#     ('A2', 'medium', 'high') (count: 40)
#       ('A10', 'f', 't') (count: 21)
#         ('A3', 'medium', 'high') (count: 3)
#           ('A13', 's', 'g') (count: 1)
#           ('A14', 'medium', 'low') (count: 1)
#         ('A14', 'medium', 'high') (count: 2)
#           ('A13', 's', 'g') (count: 1)
#           ('A3', 'low', 'high') (count: 1)
#             ('A13', 's', 'g') (count: 1)
#         ('A3', 'low', 'high') (count: 8)
#           ('A14', 'medium', 'low') (count: 3)
#             ('A13', 's', 'g') (count: 2)
#           ('A8', 'low', 'medium') (count: 2)
#             ('A13', 's', 'g') (count: 2)
#           ('A13', 's', 'g') (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#         ('A8', 'medium', 'high') (count: 2)
#         ('A13', 's', 'g') (count: 1)
#       ('A14', 'medium', 'high') (count: 2)
#         ('A3', 'low', 'high') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#       ('A3', 'low', 'high') (count: 6)
#         ('A13', 's', 'g') (count: 1)
#       ('A8', 'low', 'medium') (count: 3)
#       ('A3', 'medium', 'high') (count: 1)
#       ('A13', 's', 'g') (count: 1)
#       ('A14', 'medium', 'low') (count: 3)
#         ('A6', 'q', 'c') (count: 1)
#     ('A3', 'medium', 'high') (count: 4)
#       ('A13', 's', 'g') (count: 1)
#       ('A14', 'medium', 'low') (count: 1)
#       ('A8', 'medium', 'high') (count: 1)
#         ('A14', 'medium', 'low') (count: 1)
#     ('A13', 's', 'g') (count: 1)
#     ('A8', 'low', 'medium') (count: 14)
#       ('A14', 'medium', 'low') (count: 3)
#       ('A13', 's', 'g') (count: 1)
#     ('A14', 'medium', 'high') (count: 2)
#       ('A8', 'low', 'medium') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#       ('A3', 'low', 'high') (count: 1)
#         ('A13', 's', 'g') (count: 1)
#     ('A3', 'low', 'high') (count: 7)
#       ('A14', 'medium', 'low') (count: 1)
#       ('A8', 'low', 'medium') (count: 3)
#         ('A14', 'medium', 'low') (count: 2)
#       ('A13', 's', 'g') (count: 1)
#   ('A7', 'bb', 'v') (count: 10)
#     ('A13', 's', 'g') (count: 2)
#   ('A7', 'v', 'bb') (count: 6)
#   ('A7', 'v', 'ff') (count: 26)
#     ('A10', 'f', 't') (count: 22)
#       ('A8', 'medium', 'high') (count: 3)
#       ('A3', 'medium', 'high') (count: 11)
#         ('A14', 'medium', 'low') (count: 3)
#         ('A8', 'medium', 'high') (count: 5)
#           ('A14', 'medium', 'low') (count: 4)
#       ('A3', 'low', 'high') (count: 8)
#         ('A14', 'medium', 'low') (count: 5)
#         ('A8', 'medium', 'high') (count: 1)
#           ('A13', 's', 'g') (count: 1)
#     ('A3', 'low', 'high') (count: 2)
#       ('A8', 'medium', 'high') (count: 2)
#         ('A14', 'medium', 'low') (count: 2)
#     ('A3', 'medium', 'high') (count: 1)
#     ('A14', 'medium', 'high') (count: 1)
#       ('A8', 'medium', 'high') (count: 1)
#
# Frequent Patterns:
# Pattern: ('A10', 'f', 't'), Support: 61024
# Pattern: ('A4', 'y', 'u'), Support: 30680
# Pattern: ('A5', 'p', 'g'), Support: 27491
# Pattern: ('A14', 'medium', 'low'), Support: 22257
# Pattern: ('A3', 'low', 'high'), Support: 21342
# Pattern: ('A8', 'medium', 'high'), Support: 20084
# Pattern: ('A7', 'v', 'h'), Support: 19984
# Pattern: ('A8', 'low', 'medium'), Support: 18389
# Pattern: ('A3', 'medium', 'high'), Support: 18102
# Pattern: ('A14', 'high', 'low'), Support: 17122
# Pattern: ('A2', 'low', 'high'), Support: 16872
# Pattern: ('A2', 'medium', 'high'), Support: 16728
# Pattern: ('A14', 'medium', 'high'), Support: 15279
# Pattern: ('A1', 'b', 'a'), Support: 15006
# Pattern: ('A1', 'a', 'b'), Support: 14436
# Pattern: ('A3', 'low', 'medium'), Support: 12883
# Pattern: ('A13', 's', 'g'), Support: 12045
# Pattern: ('A4', 'u', 'y'), Support: 11925
# Pattern: ('A2', 'low', 'medium'), Support: 11568
# Pattern: ('A2', 'medium', 'low'), Support: 10945
# Pattern: ('A3', 'medium', 'low'), Support: 9861
# Pattern: ('A14', 'low', 'high'), Support: 8073
# Pattern: ('A2', 'high', 'medium'), Support: 8008
# Pattern: ('A2', 'high', 'low'), Support: 7801
# Pattern: ('A14', 'high', 'medium'), Support: 7298
# Pattern: ('A3', 'high', 'medium'), Support: 7071
# Pattern: ('A7', 'h', 'v'), Support: 7049

# %%
def format_action_rule(rule):
    """Format an action rule for readable output."""
    actions_str = []
    for feature, old_val, new_val in rule['actions']:
        actions_str.append(f"{feature}: {old_val} → {new_val}")

    return (
        f"Rule: IF {' AND '.join(actions_str)} then A16: (-) -> (+)\n"
        f"Support: {rule['support']}\n"
        f"Confidence: {rule['confidence']:.2f}\n"
        f"{'-' * 50}"
    )

def calculate_atomic_metrics(atomic_action_sets, positive_df, negative_df):
    """
    Precompute support and confidence for all atomic actions.

    Returns:
        dict: Maps (feature, old_val, new_val) to (support, confidence)
    """
    metrics = {}

    for feat, old_val, new_val in atomic_action_sets:
        # Calculate support
        neg_count = negative_df[feat].value_counts().get(old_val, 0)
        pos_count = positive_df[feat].value_counts().get(new_val, 0)
        support = neg_count * pos_count

        # Calculate confidence
        confidence = pos_count / neg_count if neg_count > 0 else 0

        metrics[(feat, old_val, new_val)] = {
            'support': support,
            'confidence': confidence
        }

    return metrics

def extract_action_rules_with_precomputed(fp_tree, atomic_metrics, min_support=4000, min_confidence=0.1):
    """Extract action rules using precomputed metrics."""
    action_rules = []

    def traverse_path(node, current_path=None):
        if current_path is None:
            current_path = []

        if node != fp_tree.root and node.action:
            current_path.append(node.action)

            if len(current_path) > 0:
                # Get precomputed metrics for this action
                metrics = atomic_metrics[node.action]

                if metrics['support'] >= min_support and metrics['confidence'] >= min_confidence:
                    action_rules.append({
                        'actions': current_path.copy(),
                        'support': metrics['support'],
                        'confidence': metrics['confidence']
                    })

        for child in node.children.values():
            traverse_path(child, current_path.copy())

    traverse_path(fp_tree.root)
    action_rules.sort(key=lambda x: (x['support'], x['confidence']), reverse=True)
    return action_rules

# Example usage with timing:
import time

# Precompute metrics
start_time = time.time()
atomic_metrics = calculate_atomic_metrics(atomic_action_sets, positive_df, negative_df)
precompute_time = time.time() - start_time

print(f"Precomputation time: {precompute_time:.2f} seconds")

# Extract rules using precomputed metrics
start_time = time.time()
rules = extract_action_rules_with_precomputed(fp_tree, atomic_metrics, min_support=8000, min_confidence=0.8)
extraction_time = time.time() - start_time

print(f"Found {len(rules)} rules")

# Print top 5 rules
print("\nTop 5 Rules by Support and Confidence:")
for rule in rules[:5]:
    print(format_action_rule(rule))

# Print some statistics about the atomic metrics
print("\nAtomic Action Statistics:")
supports = [m['support'] for m in atomic_metrics.values()]
confidences = [m['confidence'] for m in atomic_metrics.values()]

print(f"Average Support: {sum(supports) / len(supports):.2f}")
print(f"Average Confidence: {sum(confidences) / len(confidences):.2f}")
print(f"Max Support: {max(supports)}")
print(f"Max Confidence: {max(confidences):.2f}")
# Out:
# Precomputation time: 28.39 seconds
# Found 43179 rules
#
# Top 5 Rules by Support and Confidence:
# Rule: IF A12: t → f AND A3: high → low AND A14: high → medium AND A2: medium → low AND A5: p → g then A16: (-) -> (+)
# Support: 30680
# Confidence: 2.20
# --------------------------------------------------
# Rule: IF A12: t → f AND A3: high → low AND A14: high → medium AND A2: medium → low AND A5: p → g AND A4: y → u then A16: (-) -> (+)
# Support: 30680
# Confidence: 2.20
# --------------------------------------------------
# Rule: IF A12: t → f AND A3: high → low AND A14: high → medium AND A5: p → g then A16: (-) -> (+)
# Support: 30680
# Confidence: 2.20
# --------------------------------------------------
# Rule: IF A12: t → f AND A3: high → low AND A14: high → medium AND A5: p → g AND A4: y → u then A16: (-) -> (+)
# Support: 30680
# Confidence: 2.20
# --------------------------------------------------
# Rule: IF A12: t → f AND A3: high → low AND A2: medium → low AND A13: g → s AND A5: p → g then A16: (-) -> (+)
# Support: 30680
# Confidence: 2.20
# --------------------------------------------------
#
# Atomic Action Statistics:
# Average Support: 30.16
# Average Confidence: 0.57
# Max Support: 97006
# Max Confidence: 173.00
